# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataclasses import dataclass, field
import coulomb as cb
    
exp_data = pd.read_csv(f'../data/garsany_et_al_2018/Garsany2018-gz.csv', sep=';', decimal=',')
exp_data = exp_data[exp_data.cell_id != 'GORE']
cells = exp_data.cell_id.unique()
for cell in cells: 
    exp_data.loc[exp_data.cell_id  == cell, 'case'] = exp_data.loc[exp_data.cell_id  == cell, ['T_stack', 'rh_ca', 'rh_an', 'p_ca_out']].sum(axis=1)
case_list = [1,2,3]
exp_data['case'] = exp_data['case'].map(dict(zip(exp_data['case'].unique(),case_list)))
exp_data
# Out:
#          i       U  T_stack  rh_ca  rh_an       st_ca       st_an  x_o2_ca  \
# 0   0.0113  0.9005   353.15    1.0    1.0  100.884956  100.884956      0.2
# 1   0.0198  0.8797   353.15    1.0    1.0   57.575758   57.575758      0.2
# 2   0.0594  0.8499   353.15    1.0    1.0   19.191919   19.191919      0.2
# 3   0.1876  0.8012   353.15    1.0    1.0    6.076759    6.076759      0.2
# 4   0.4047  0.7396   353.15    1.0    1.0    2.816901    2.816901      0.2
# ..     ...     ...      ...    ...    ...         ...         ...      ...
# 91  1.6031  0.6016   353.15    1.0    1.0    2.000000    2.000000      0.2
# 92  1.8349  0.5505   353.15    1.0    1.0    2.000000    2.000000      0.2
# 93  2.0216  0.5006   353.15    1.0    1.0    2.000000    2.000000      0.2
# 94  2.1860  0.4510   353.15    1.0    1.0    2.000000    2.000000      0.2
# 95  2.3302  0.4013   353.15    1.0    1.0    2.000000    2.000000      0.2
#
#     p_ca_out  p_an_out figure       cell_id       hfr  case
# 0     101000    101000     7a    LSC Nafion       NaN     1
# 1     101000    101000     7a    LSC Nafion       NaN     1
# 2     101000    101000     7a    LSC Nafion       NaN     1
# 3     101000    101000     7a    LSC Nafion  0.000006     1
# 4     101000    101000     7a    LSC Nafion  0.000006     1
# ..       ...       ...    ...           ...       ...   ...
# 91    150000    150000     8a  SSC Aquivion  0.000005     3
# 92    150000    150000     8a  SSC Aquivion  0.000005     3
# 93    150000    150000     8a  SSC Aquivion  0.000006     3
# 94    150000    150000     8a  SSC Aquivion  0.000006     3
# 95    150000    150000     8a  SSC Aquivion  0.000006     3
#
# [72 rows x 14 columns]

# %%
def compute_ui_curve(cell, case): 
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell.name)]
        current_density = np.maximum(1,1e4*case_exp_data['i'].values)
        cathode_conditions = cb.OperatingConditions(
            inlet_temperature = case_exp_data['T_stack'].values,
            inlet_relative_humidity=case_exp_data['rh_ca'].values,
            outlet_pressure=case_exp_data['p_ca_out'].values,
            dry_o2_mole_fraction=0.21,
            dry_h2_mole_fraction=0,
            stoichiometry=case_exp_data['st_ca'].values,
        )
        anode_conditions = cb.OperatingConditions(
            inlet_temperature = case_exp_data['T_stack'].values,
            inlet_relative_humidity=case_exp_data['rh_an'].values,
            outlet_pressure=case_exp_data['p_an_out'].values,
            dry_o2_mole_fraction=0,
            dry_h2_mole_fraction=1,
            stoichiometry=case_exp_data['st_an'].values,
        )

        cell.set_conditions(case_exp_data['T_stack'].values, 
                                 current_density,cathode_conditions, anode_conditions)

        
        cell.calculate_heat_transfer_resistance()
        mea_temperature = fuel_cell.temperature + (cell.current_density * 0.7) * cell.thermal_resistance
        cell.set_mea_temperature(mea_temperature)
       
        cell.calculate_water_transport()
        # s_ca_cl = fuel_cell.ca.cl.water_saturation
        # fuel_cell.membrane.water_content = fuel_cell.membrane.water_content * (1-s_ca_cl) + s_ca_cl * 22
        # fuel_cell.ca.cl.water_content = fuel_cell.ca.cl.water_content * (1-s_ca_cl) + s_ca_cl * 22
        cell.calculate_reactant_concentration_at_cl()
        
       # fuel_cell.solve_transport() 
        return cell.cell_voltage()

# %%
class HydrogenPermeationModel:
    def __init__(self): 
        pass 

    def permeation_flux(self,
                        membrane_thickness: float,
                        partial_pressure_h2: float,
                        temperature: float,
                        pressure_difference: float,
                        water_vol_fraction: float
        ) -> float:
        D_h2_w = 2.205e-9
        S_h2_w = 7.12e-6
        k_l_mb = 1.6e-18
        mu_w = cb.water.water_dynamic_viscosity(temperature)
        h2_permeability = (D_h2_w + water_vol_fraction * k_l_mb / mu_w * pressure_difference) * S_h2_w
        return h2_permeability * 1e-3 * partial_pressure_h2 / membrane_thickness
    
class ChannelGasResistanceModel: 
    def __init__(self, A_cell): 
        self.A_cell = A_cell

    def total_resistance(self, channel, diffusion_coefficient, volume_flow_rate): 
        return self.A_cell / volume_flow_rate / 2


@dataclass 
class CatalystLayerIonomerModel: 
    density: float = 2004 
    equivalent_weight: float = 952. 
    hydrated_proton_conductivity: float = 11 # S/m
    proton_conductivity_exponent: float = 2.7

    def o2_film_resistance(self, water_content, temperature= 353.15):
        # Linear regression of data from Jinnouchi et al. (2021), neglecting bulk diffusion.
        # Activation energy obtained by Kudo et al. (2006).
        return 1.14698e-10 * (water_content/14) ** 0.708 #* cb.calculate_arrhenius_term(-24e6, temperature, 353.15)

    def proton_conductivity(self, relative_humidity, water_content, temperature):
        return self.hydrated_proton_conductivity * (water_content/14.) ** (self.proton_conductivity_exponent) * cb.calculate_arrhenius_term(11e6, temperature, 353.15) # Following measurements of Hutapea et al. (2023)

@dataclass
class PorousLiquidTransportModel: 
    critical_damkholer: float = 1.
    dry_wet_transition_parameter: float = 10

    def vapor_transport_resistance(self, cell_side): 
        return cell_side.calculate_gas_transport_resistance('h2o')
    
    def calculate_damkholer_number(self, cell_side, water_injection_flux): 
        cl_sat_concentration = cell_side.cl.get_saturation_concentration()
        ch_vapor_concentration = cell_side.ch.get_vapor_concentration()
        max_vapor_removal_flux = (cl_sat_concentration - ch_vapor_concentration) / cell_side.h2ov_transport_resistance
        return water_injection_flux / max_vapor_removal_flux
        
    def calculate_water_saturation(self, cell_side, water_injection_flux): 
        #damkholer = self.calculate_damkholer_number(cell_side, water_injection_flux)
        cl_sat_concentration = cell_side.cl.get_saturation_concentration()
        ch_vapor_concentration = cell_side.ch.get_vapor_concentration()
        max_vapor_removal_flux = (cl_sat_concentration - ch_vapor_concentration) / cell_side.h2ov_transport_resistance
        #return self.wet_saturation *  cb.sigmoid(water_injection_flux, max_vapor_removal_flux * self.critical_damkholer, self.dry_wet_transition_parameter)
        return (np.maximum(water_injection_flux-max_vapor_removal_flux * self.critical_damkholer,1e-12) / cell_side.gdl.absolute_permeability) ** self.dry_wet_transition_parameter

# %%
def create_fuel_cell(params, cell): 

    ORRkinetics=cb.ElectrochemicalReaction(
                    reference_exchange_current_density=params['i0-c'],
                    reaction_order=params['gamma-c'], 
                    activation_energy=67e6, 
                    reference_activity=1.01325e5,
                    reference_temperature=353.15,
                    number_of_electrons=2,
                    charge_transfer_coeff=0.5
                )
    
    IonomerAquivionD83=cb.CatalystLayerIonomerModel(equivalent_weight=830.,
        hydrated_proton_conductivity=params['AquivionD83-06-cl-proton-cond'],
        proton_conductivity_rh_exponent=0, 
        proton_conductivity_water_content_exponent=params['AquivionD83-06-cl-proton-cond-exp'],
        hydrated_o2_diffusion=params['AquivionD83-06-o2-diff'],
        o2_diffusion_exponent=params['AquivionD83-06-cl-o2-diff-exp'])
    
    IonomerNafionLQ1115=cb.CatalystLayerIonomerModel(equivalent_weight=1100.,
        hydrated_proton_conductivity=params['NafionLQ1115-cl-proton-cond'],
        proton_conductivity_rh_exponent=0,
        proton_conductivity_water_content_exponent=params['AquivionD83-06-cl-proton-cond-exp'], 
        hydrated_o2_diffusion=params['NafionLQ1115-o2-diff'], 
        o2_diffusion_exponent=params['AquivionD83-06-cl-o2-diff-exp'])

    AquivionCL = cb.CatalystLayer(
        platinum_loading=0.31e-2, 
        thickness=8e-6, 
        ionomer=IonomerAquivionD83,
        reaction=ORRkinetics,
        ecsa=61e3, 
        ionomer_to_carbon_ratio=0.95,
        pore_diameter=params['AquivionD83-06-pore-diameter'],
        catalyst_platinum_weight_percent=0.5, 
        thermal_conductivity=0.25,
        carbon_agglomerate_radius=100e-9,
        absolute_permeability=params['Aquivion-cl-K-abs'],
        contact_angle=95.,
        omega_PtO=0) 

    NafionCL = cb.CatalystLayer(
        platinum_loading=0.31e-2, 
        thickness=7.8e-6, 
        ionomer=IonomerNafionLQ1115,
        reaction=ORRkinetics,
        ecsa=65e3, 
        ionomer_to_carbon_ratio=0.95,
        carbon_agglomerate_radius=100e-9,
        pore_diameter=params['NafionLQ1115-pore-diameter'],
        catalyst_platinum_weight_percent=0.5, 
        absolute_permeability=params['Nafion-cl-K-abs'],
        contact_angle=95.,
        thermal_conductivity=0.25,
        omega_PtO=0) 

    GDL3Mca = cb.PorousLayer(
        thickness=236e-6,
        effective_gas_diffusion_ratio=params['3M-Deff-ratio'], 
        absolute_permeability=params['Kabs'], 
        thermal_conductivity=1./params['kth-gdl'],
        porosity=0.6,
        contact_angle=120.)

    GDL3Man = cb.PorousLayer(
        thickness=266e-6,
        effective_gas_diffusion_ratio=params['3M-Deff-ratio'],
        thermal_conductivity=1./params['kth-gdl'],
        absolute_permeability=params['Kabs'], 
        porosity=0.6,
        contact_angle=120.) 
    
    NafionHP = cb.Membrane(
        dry_thickness=20.3e-6, 
        conductivity_correction=params['NafionHP-conductivity-correction'],
        conductivity_exp=params['NafionHP-conductivity-exp'],
        water_balance_model=cb.MembraneWaterBalanceModel(
            reference_water_chemical_diffusion_coefficient=params['Nafion-memb-diff'],
            reference_absorption_coefficient=params['Nafion-memb-abs-constant'] if cell == 'LSC Nafion' else params['Aquivion-memb-abs-constant'])
    )
    fc = cb.FuelCell(
        electrical_resistance=params['elec-resistance'],
        cell_area = 10e-4, 
        cell_number = 1, 
        ca = cb.FuelCellSide(
            cl=NafionCL if cell=='LSC Nafion' else AquivionCL, has_mpl=False, gdl=GDL3Mca,  
            ch=cb.GasFlowChannel(
                reactant='o2',
                height=1e-3, 
                length=10e-4/2e-3,
                n_parallel=1,
                transport_resistance_model = cb.ChannelGasResistanceModel(A_ch=params['A_ch'], B_ch=params['B_ch'])
            ),
            liq_transport_model=cb.DarcyLiquidTransportModel(
                dry_wet_transition_parameter=params['wet-transition'],
            ),
            thermal_contact_resistance=2e-4,
        ),
        an = cb.FuelCellSide(
            cl=NafionCL, has_mpl=False, gdl=GDL3Man,
            ch=cb.GasFlowChannel(
                reactant='h2',
                height=1e-3, 
                length=10e-4/2e-3,
                n_parallel=1,
                transport_resistance_model = cb.ChannelGasResistanceModel(A_ch=params['A_ch'],B_ch=params['B_ch'])
            ),
            thermal_contact_resistance=2e-4,
        ),
        membrane = NafionHP
    )
    fc.name=cell
    return fc

# %%
def h(params): 
    fuel_cells = {cell: create_fuel_cell(params,  cell) for cell in cells}
    return np.concatenate(
         [compute_ui_curve(fuel_cells[cell], case) for case in case_list for cell in cells if case in exp_data[exp_data.cell_id == cell].case.unique()]
    )
exp_voltage_list = np.concatenate(
         [exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'U'] for case in case_list for cell in cells if case in exp_data[exp_data.cell_id == cell].case.unique()]
    )

def h2(params): 
    res_list = []
    fuel_cells = {cell: create_fuel_cell(params,  cell) for cell in cells}
    for case in case_list: 
        for cell in cells: 
            if case in exp_data[exp_data.cell_id == cell].case.unique(): 
                V_sim = compute_ui_curve(fuel_cells[cell], case)
                hfr_sim = 1e4*fuel_cells[cell].high_frequency_resistance() * (1-np.isnan(exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'hfr']))
                res_list += [V_sim, hfr_sim]
    return np.concatenate(res_list)
exp_res_list = []
for case in case_list: 
        for cell in cells: 
            if case in exp_data[exp_data.cell_id == cell].case.unique(): 
                V_exp = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'U']
                hfr_exp = np.nan_to_num(1e4*exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'hfr'],0)
                exp_res_list += [V_exp, hfr_exp]
exp_res_list = np.concatenate(exp_res_list)


model = cb.ParameterEstimationSteadyState(h2, {'AquivionD83-06-cl-proton-cond-exp': 1.85,
        'AquivionD83-06-pore-diameter':120e-9, 
        'NafionLQ1115-pore-diameter':120e-9, 
        'i0-c': 3.82e-4, 
        'gamma-c': 0.54,
        'NafionLQ1115-cl-proton-cond-exp':2.41, 
        'NafionHP-conductivity-exp': 1, 
        'Aquivion-cl-K-abs': 1e-13, 
        'Nafion-cl-K-abs': 1e-13,
        'Nafion-memb-diff': 4.3e-10,
        'NafionLQ1115-cl-proton-cond':22.1, 
        'AquivionD83-06-cl-proton-cond-exp': 3.33,
        'AquivionD83-06-cl-proton-cond': 135,
        'NafionLQ1115-cl-o2-diff-exp': 0.7,
        'AquivionD83-06-cl-o2-diff-exp':0.7,
        'elec-resistance':40e-7,
        'NafionHP-conductivity-correction': 1.12e+00, 
        'Nafion-memb-abs-constant': 10e-6, 
        'Aquivion-memb-abs-constant': 2e-5, 
        'NafionLQ1115-o2-diff': 4e-10,
        'AquivionD83-06-o2-diff': 8.65e-10,
        '3M-Deff-ratio': 0.338,  
        'wet-transition': 0.2, 
        'B_ch': 1, 
        'A_ch': 1,  
        'kth-gdl':0.5,
        'Kabs': 1e-12
        })

'''
------------------------------
differential_evolution step 202: f(x)= 0.00020593796258720597
------------------------------
RMSE : 14.4 mV
AquivionD83-06-cl-proton-cond (1, 200) 1.35e+02
NafionLQ1115-cl-proton-cond (1, 200) 2.21e+01
AquivionD83-06-cl-proton-cond-exp (1, 4) 3.33e+00
NafionLQ1115-cl-proton-cond-exp (1, 4) 2.41e+00
AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.94e-09
NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.47e-08
AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.66e+00
NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.61e-01
NafionHP-conductivity-correction (0.5, 2) 1.78e+00
NafionHP-conductivity-exp (1, 2) 1.04e+00
Nafion-memb-abs-constant (1e-06, 0.0001) 4.59e-06
Aquivion-memb-abs-constant (1e-06, 0.0001) 1.99e-05
NafionLQ1115-o2-diff (1e-12, 1e-09) 1.88e-10
AquivionD83-06-o2-diff (1e-12, 1e-09) 8.65e-10
3M-Deff-ratio (0.15, 0.5) 3.38e-01
i0-c (1e-05, 0.001) 3.82e-04
elec-resistance (2e-06, 6e-06) 3.95e-06
A_ch (0.0001, 2) 1.56e-01
B_ch (0.0001, 2) 1.56e-02
wet-transition (0.0, 0.4) 3.57e-01
kth-gdl (0.05, 5) 5.00e-02
------------------------------
'''

for i_cell, cell in enumerate(['LSC Nafion', 'SSC Aquivion']): 
    for k, case in enumerate(case_list): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]

        plt.figure(1)
        plt.plot(fuel_cell.current_density/1e4, U_sim, 'C{}-'.format(k) + ('-' if i_cell == 1 else ''))
        plt.plot(case_exp_data['i'].values, case_exp_data['U'].values, 'C{}'.format(k) + ('s' if i_cell == 0 else 'o'))
        plt.figure(2)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.gdl.water_saturation, 'C{}-'.format(k) + '-' if i_cell == 1 else '')
        plt.figure(3)
        plt.plot(fuel_cell.current_density/1e4, 1e7*fuel_cell.high_frequency_resistance(), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
        plt.figure(4)
        plt.plot(fuel_cell.current_density/1e4,fuel_cell.ca.calculate_gas_transport_resistance('h2o'), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
        plt.figure(5)
        plt.plot(fuel_cell.current_density/1e4,fuel_cell.membrane.water_content, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
exp_res_list
# Out:
# array([0.9005, 0.8797, 0.8499, 0.8012, 0.7396, 0.6973, 0.6398, 0.5997,
#        0.5493, 0.4999, 0.4495, 0.4005, 0.    , 0.    , 0.    , 0.0614,
#        0.0558, 0.0545, 0.0536, 0.054 , 0.0547, 0.056 , 0.0582, 0.0606,
#        0.8976, 0.8752, 0.8491, 0.8011, 0.7396, 0.7009, 0.639 , 0.6003,
#        0.5489, 0.4997, 0.4494, 0.4005, 0.    , 0.    , 0.    , 0.0514,
#        0.0423, 0.0412, 0.0411, 0.0413, 0.0423, 0.0439, 0.0471, 0.051 ,
#        0.8981, 0.8769, 0.8478, 0.8007, 0.7371, 0.6991, 0.6401, 0.5999,
#        0.5497, 0.5008, 0.4501, 0.4011, 0.    , 0.    , 0.129 , 0.103 ,
#        0.0886, 0.0851, 0.0834, 0.0868, 0.0903, 0.0946, 0.099 , 0.105 ,
#        0.8994, 0.8796, 0.8505, 0.8002, 0.7406, 0.698 , 0.6392, 0.5997,
#        0.5501, 0.4998, 0.451 , 0.4012, 0.    , 0.    , 0.121 , 0.0964,
#        0.0834, 0.0799, 0.0816, 0.0842, 0.0899, 0.0946, 0.101 , 0.106 ,
#        0.9004, 0.8819, 0.8523, 0.8017, 0.7409, 0.7016, 0.6414, 0.6013,
#        0.5509, 0.5002, 0.451 , 0.4008, 0.    , 0.    , 0.0688, 0.0575,
#        0.0542, 0.0539, 0.0529, 0.0534, 0.0552, 0.0571, 0.0599, 0.0633,
#        0.9018, 0.8824, 0.8522, 0.7976, 0.744 , 0.7017, 0.6416, 0.6016,
#        0.5505, 0.5006, 0.451 , 0.4013, 0.    , 0.    , 0.0596, 0.0525,
#        0.0504, 0.0508, 0.0517, 0.0527, 0.0546, 0.0569, 0.0599, 0.0631])

# %%
model.set_unknown_params(
        [
        ('AquivionD83-06-cl-proton-cond', (1, 200), True, r'$\sigma_{Aquivion}$'),
        ('NafionLQ1115-cl-proton-cond', (1,200), True, r'$\sigma_{Nafion}$'),
        ('AquivionD83-06-cl-proton-cond-exp', (2, 4), True, r'$m\sigma_{Aquivion}$'),
        #('NafionLQ1115-cl-proton-cond-exp', (2,4), True, r'$m\sigma_{Nafion}$'),
        ('AquivionD83-06-pore-diameter', (1e-9, 200e-9), True, r'$dp_{Aquivion}$'),
        ('NafionLQ1115-pore-diameter', (1e-9, 200e-9), True, r'$dp_{Nafion}$'),
        ('AquivionD83-06-cl-o2-diff-exp', (0.2, 2), True, r'$\sigma_{Aquivion}$'),
        #('NafionLQ1115-cl-o2-diff-exp', (.5,2), True, r'$\sigma_{Nafion}$'),
        ('NafionHP-conductivity-correction', (0.5,5), True, '$k_{cond}$'),
        ('NafionHP-conductivity-exp', (1,2), True, '$m_{k}$'),
        ('Nafion-memb-abs-constant', (1e-6,1e-2), False, '$k_{abs}$'),
        ('Aquivion-memb-abs-constant', (1e-6,1e-2), False, '$k_{abs,Aq}$'),
        ('NafionLQ1115-o2-diff', (1e-12,10e-9), True, '$D_{O2,Nafion}$'),
        ('AquivionD83-06-o2-diff', (1e-12,10e-9), True, '$D_{O2,Aquivion}$'),
        ('3M-Deff-ratio', (0.15,0.6), True, '$D_{eff}/D$'),
        ('Nafion-memb-diff', (1e-10,10e-8), False, '$D_{\lambda}$'),
        ('i0-c',(1e-5,1e-3), False, '$i0_c$'),
        #('memb-thickness', (20e-6, 25e-6), True, '$t_m$'), 
        ('elec-resistance', (20e-7,60e-7), True, '$R_{elec}$'),
        
        ('A_ch', (0, 2), True, '$A_{ch}$'),
        ('B_ch', (0, 2), True, '$B_{ch}$'),
        #('ionomer-vol-fraction', (0.15,0.4), True, r'$\varepsilon_{ion}$'),
        ('Kabs', (1e-13,1e-10), False, '$K_{l}$'),
        # ('Aquivion-cl-K-abs', (1e-14,1e-12), False, '$K_{l}$'),
        # ('Nafion-cl-K-abs', (1e-14, 1e-12), False, '$K_{l}$'),
        #('wet-saturation', (0.1,0.5), True, '$s_{wet}$'),
        ('wet-transition', (0.1, 0.4), True, '$alpha_{wet}$'),
        #('critical-damkholer', (0.8,2), True, '$Da_{w,cr}$'),
        ('kth-gdl', (1./5,1./0.03), True, '$k_{GDL}$'),
        #('R-ch-correction', (0.,1.), True, '$R_{ch}$'),
        
        #('ionomer-vol-fraction', (0.1,.5), True, '$\epsilon_{ion}$'),
        #('E-act-ca', (50e3, 100e3), True, '$E_{act, ca}$'),
        #('omega-PtO', (1e6, 10e6), True, '$\omega_{PtO}$'),
        #('memb-cond-corr', (0.1,10), True,'$f_{mb}$'),
        #('memb-water-diff', (1e-10, 40e-10), True, '$D_{\lambda}$'),
        #('memb-abs-constant', (1e-7, 1e-4), False, '$k_{abs}$'),
        ]
    )

# %%
cosPhi_med_ij, norm_s_i, S_med, S_std, S_med_i, S_std_i, S_n, n_valid = model.compute_global_sensitivity(t=0, m=6,  
                                                                                                         check_samples=True,
                                                                                                         y_exp=exp_res_list, 
                                                                                                         res_limit=0.02)

# %%
print('Number of valid samples: {:d}'.format(n_valid))
fig1, ax1 = model.plot_global_sensitivity(xlabel_angle=45) 
fig2, ax2 = model.plot_colinearity_map(xlabel_angle=45, cmap='Blues',figsize=(7,6))

plt.show()
# Out:
# Number of valid samples: 29

# %%
sol, p_est = model.estimate(exp_res_list, t=0, print_iterations=True, popsize=40, ftol=1e-5)
model.p.update({param: v for param, v in zip(model.p_i_name, p_est)})
# Out:
# differential_evolution step 1: f(x)= 0.0004621071589682639
# ------------------------------
# RMSE : 21.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.01e+02
# NafionLQ1115-cl-proton-cond (1, 200) 9.56e+01
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.31e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.14e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.18e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.93e-01
# NafionHP-conductivity-correction (0.5, 5) 3.56e+00
# NafionHP-conductivity-exp (1, 2) 1.07e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 3.59e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.49e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.32e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 9.50e-09
# 3M-Deff-ratio (0.15, 0.6) 4.56e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.87e-10
# i0-c (1e-05, 0.001) 4.68e-04
# elec-resistance (2e-06, 6e-06) 4.97e-06
# A_ch (0, 2) 9.84e-01
# B_ch (0, 2) 2.42e-03
# Kabs (1e-13, 1e-10) 4.26e-13
# wet-transition (0.1, 0.4) 3.06e-01
# kth-gdl (0.2, 33.333333333333336) 2.35e+01
# ------------------------------
# differential_evolution step 2: f(x)= 0.0004621071589682639
# ------------------------------
# RMSE : 21.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.01e+02
# NafionLQ1115-cl-proton-cond (1, 200) 9.56e+01
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.31e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.14e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.18e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.93e-01
# NafionHP-conductivity-correction (0.5, 5) 3.56e+00
# NafionHP-conductivity-exp (1, 2) 1.07e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 3.59e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.49e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.32e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 9.50e-09
# 3M-Deff-ratio (0.15, 0.6) 4.56e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.87e-10
# i0-c (1e-05, 0.001) 4.68e-04
# elec-resistance (2e-06, 6e-06) 4.97e-06
# A_ch (0, 2) 9.84e-01
# B_ch (0, 2) 2.42e-03
# Kabs (1e-13, 1e-10) 4.26e-13
# wet-transition (0.1, 0.4) 3.06e-01
# kth-gdl (0.2, 33.333333333333336) 2.35e+01
# ------------------------------
# differential_evolution step 3: f(x)= 0.0004207350622753645
# ------------------------------
# RMSE : 20.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 8.78e+01
# NafionLQ1115-cl-proton-cond (1, 200) 7.94e+01
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.21e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.88e-07
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 4.46e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 7.10e-01
# NafionHP-conductivity-correction (0.5, 5) 4.43e+00
# NafionHP-conductivity-exp (1, 2) 1.29e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.54e-05
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.27e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 3.74e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.36e-09
# 3M-Deff-ratio (0.15, 0.6) 3.40e-01
# Nafion-memb-diff (1e-10, 1e-07) 6.65e-10
# i0-c (1e-05, 0.001) 3.51e-04
# elec-resistance (2e-06, 6e-06) 5.08e-06
# A_ch (0, 2) 1.43e+00
# B_ch (0, 2) 7.96e-02
# Kabs (1e-13, 1e-10) 5.70e-13
# wet-transition (0.1, 0.4) 2.20e-01
# kth-gdl (0.2, 33.333333333333336) 1.82e+01
# ------------------------------
# differential_evolution step 4: f(x)= 0.00033923713769716036
# ------------------------------
# RMSE : 18.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.43e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.25e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.35e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.83e-07
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.43e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 5.03e-01
# NafionHP-conductivity-correction (0.5, 5) 4.05e+00
# NafionHP-conductivity-exp (1, 2) 1.28e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 7.06e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.07e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.31e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.16e-09
# 3M-Deff-ratio (0.15, 0.6) 2.09e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.10e-10
# i0-c (1e-05, 0.001) 2.46e-04
# elec-resistance (2e-06, 6e-06) 4.78e-06
# A_ch (0, 2) 1.29e+00
# B_ch (0, 2) 9.27e-02
# Kabs (1e-13, 1e-10) 1.78e-12
# wet-transition (0.1, 0.4) 3.78e-01
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 5: f(x)= 0.00033923713769716036
# ------------------------------
# RMSE : 18.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.43e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.25e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.35e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.83e-07
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.43e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 5.03e-01
# NafionHP-conductivity-correction (0.5, 5) 4.05e+00
# NafionHP-conductivity-exp (1, 2) 1.28e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 7.06e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.07e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.31e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.16e-09
# 3M-Deff-ratio (0.15, 0.6) 2.09e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.10e-10
# i0-c (1e-05, 0.001) 2.46e-04
# elec-resistance (2e-06, 6e-06) 4.78e-06
# A_ch (0, 2) 1.29e+00
# B_ch (0, 2) 9.27e-02
# Kabs (1e-13, 1e-10) 1.78e-12
# wet-transition (0.1, 0.4) 3.78e-01
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 6: f(x)= 0.00033923713769716036
# ------------------------------
# RMSE : 18.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.43e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.25e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.35e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.83e-07
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.43e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 5.03e-01
# NafionHP-conductivity-correction (0.5, 5) 4.05e+00
# NafionHP-conductivity-exp (1, 2) 1.28e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 7.06e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.07e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.31e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.16e-09
# 3M-Deff-ratio (0.15, 0.6) 2.09e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.10e-10
# i0-c (1e-05, 0.001) 2.46e-04
# elec-resistance (2e-06, 6e-06) 4.78e-06
# A_ch (0, 2) 1.29e+00
# B_ch (0, 2) 9.27e-02
# Kabs (1e-13, 1e-10) 1.78e-12
# wet-transition (0.1, 0.4) 3.78e-01
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 7: f(x)= 0.000295606400529115
# ------------------------------
# RMSE : 17.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.16e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.34e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 9.30e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.42e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.15e-01
# NafionHP-conductivity-correction (0.5, 5) 4.05e+00
# NafionHP-conductivity-exp (1, 2) 1.28e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 7.74e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.31e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.76e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.50e-09
# 3M-Deff-ratio (0.15, 0.6) 1.72e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.96e-10
# i0-c (1e-05, 0.001) 2.73e-04
# elec-resistance (2e-06, 6e-06) 4.69e-06
# A_ch (0, 2) 1.23e+00
# B_ch (0, 2) 1.15e-01
# Kabs (1e-13, 1e-10) 5.39e-13
# wet-transition (0.1, 0.4) 2.34e-01
# kth-gdl (0.2, 33.333333333333336) 1.70e+01
# ------------------------------
# differential_evolution step 8: f(x)= 0.00027719291616897505
# ------------------------------
# RMSE : 16.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.18e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.27e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.28e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.93e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.31e-01
# NafionHP-conductivity-correction (0.5, 5) 3.87e+00
# NafionHP-conductivity-exp (1, 2) 1.26e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 8.95e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.55e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.29e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.38e-09
# 3M-Deff-ratio (0.15, 0.6) 1.62e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.47e-10
# i0-c (1e-05, 0.001) 4.19e-04
# elec-resistance (2e-06, 6e-06) 5.15e-06
# A_ch (0, 2) 1.24e+00
# B_ch (0, 2) 3.51e-02
# Kabs (1e-13, 1e-10) 3.85e-13
# wet-transition (0.1, 0.4) 2.31e-01
# kth-gdl (0.2, 33.333333333333336) 1.87e+01
# ------------------------------
# differential_evolution step 9: f(x)= 0.00027719291616897505
# ------------------------------
# RMSE : 16.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.18e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.27e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.28e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.93e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.31e-01
# NafionHP-conductivity-correction (0.5, 5) 3.87e+00
# NafionHP-conductivity-exp (1, 2) 1.26e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 8.95e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.55e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.29e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.38e-09
# 3M-Deff-ratio (0.15, 0.6) 1.62e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.47e-10
# i0-c (1e-05, 0.001) 4.19e-04
# elec-resistance (2e-06, 6e-06) 5.15e-06
# A_ch (0, 2) 1.24e+00
# B_ch (0, 2) 3.51e-02
# Kabs (1e-13, 1e-10) 3.85e-13
# wet-transition (0.1, 0.4) 2.31e-01
# kth-gdl (0.2, 33.333333333333336) 1.87e+01
# ------------------------------
# differential_evolution step 10: f(x)= 0.00027719291616897505
# ------------------------------
# RMSE : 16.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.18e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.27e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.28e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.93e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.31e-01
# NafionHP-conductivity-correction (0.5, 5) 3.87e+00
# NafionHP-conductivity-exp (1, 2) 1.26e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 8.95e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.55e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.29e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.38e-09
# 3M-Deff-ratio (0.15, 0.6) 1.62e-01
# Nafion-memb-diff (1e-10, 1e-07) 3.47e-10
# i0-c (1e-05, 0.001) 4.19e-04
# elec-resistance (2e-06, 6e-06) 5.15e-06
# A_ch (0, 2) 1.24e+00
# B_ch (0, 2) 3.51e-02
# Kabs (1e-13, 1e-10) 3.85e-13
# wet-transition (0.1, 0.4) 2.31e-01
# kth-gdl (0.2, 33.333333333333336) 1.87e+01
# ------------------------------
# differential_evolution step 11: f(x)= 0.0002663220063394886
# ------------------------------
# RMSE : 16.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 8.78e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.24e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.86e-07
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.28e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.77e-01
# NafionHP-conductivity-correction (0.5, 5) 4.43e+00
# NafionHP-conductivity-exp (1, 2) 1.35e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 7.04e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.93e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.31e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 2.82e-09
# 3M-Deff-ratio (0.15, 0.6) 2.17e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.62e-10
# i0-c (1e-05, 0.001) 3.46e-04
# elec-resistance (2e-06, 6e-06) 4.05e-06
# A_ch (0, 2) 4.69e-01
# B_ch (0, 2) 6.71e-01
# Kabs (1e-13, 1e-10) 5.19e-12
# wet-transition (0.1, 0.4) 2.66e-01
# kth-gdl (0.2, 33.333333333333336) 1.68e+01
# ------------------------------
# differential_evolution step 12: f(x)= 0.00022581160046255825
# ------------------------------
# RMSE : 15.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.16e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.17e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.26e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.67e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.12e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.04e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.37e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 9.55e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.28e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.04e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.39e-09
# 3M-Deff-ratio (0.15, 0.6) 2.18e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.76e-09
# i0-c (1e-05, 0.001) 3.43e-04
# elec-resistance (2e-06, 6e-06) 4.66e-06
# A_ch (0, 2) 4.03e-01
# B_ch (0, 2) 7.11e-01
# Kabs (1e-13, 1e-10) 2.46e-12
# wet-transition (0.1, 0.4) 2.12e-01
# kth-gdl (0.2, 33.333333333333336) 1.71e+01
# ------------------------------
# differential_evolution step 13: f(x)= 0.00022581160046255825
# ------------------------------
# RMSE : 15.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.16e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.17e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.26e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.67e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.12e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.04e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.37e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 9.55e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.28e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.04e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.39e-09
# 3M-Deff-ratio (0.15, 0.6) 2.18e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.76e-09
# i0-c (1e-05, 0.001) 3.43e-04
# elec-resistance (2e-06, 6e-06) 4.66e-06
# A_ch (0, 2) 4.03e-01
# B_ch (0, 2) 7.11e-01
# Kabs (1e-13, 1e-10) 2.46e-12
# wet-transition (0.1, 0.4) 2.12e-01
# kth-gdl (0.2, 33.333333333333336) 1.71e+01
# ------------------------------
# differential_evolution step 14: f(x)= 0.00022581160046255825
# ------------------------------
# RMSE : 15.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.16e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.17e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.26e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 8.67e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 5.12e-08
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.04e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.37e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 9.55e-06
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.28e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.04e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.39e-09
# 3M-Deff-ratio (0.15, 0.6) 2.18e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.76e-09
# i0-c (1e-05, 0.001) 3.43e-04
# elec-resistance (2e-06, 6e-06) 4.66e-06
# A_ch (0, 2) 4.03e-01
# B_ch (0, 2) 7.11e-01
# Kabs (1e-13, 1e-10) 2.46e-12
# wet-transition (0.1, 0.4) 2.12e-01
# kth-gdl (0.2, 33.333333333333336) 1.71e+01
# ------------------------------
# differential_evolution step 15: f(x)= 0.00022326044059794742
# ------------------------------
# RMSE : 14.9 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.17e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.16e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.17e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.49e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.55e-01
# NafionHP-conductivity-correction (0.5, 5) 4.14e+00
# NafionHP-conductivity-exp (1, 2) 1.37e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 3.56e-05
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.31e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.06e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.46e-09
# 3M-Deff-ratio (0.15, 0.6) 2.17e-01
# Nafion-memb-diff (1e-10, 1e-07) 4.27e-09
# i0-c (1e-05, 0.001) 3.40e-04
# elec-resistance (2e-06, 6e-06) 4.67e-06
# A_ch (0, 2) 4.00e-01
# B_ch (0, 2) 6.88e-01
# Kabs (1e-13, 1e-10) 2.11e-12
# wet-transition (0.1, 0.4) 3.29e-01
# kth-gdl (0.2, 33.333333333333336) 1.72e+01
# ------------------------------
# differential_evolution step 16: f(x)= 0.00022326044059794742
# ------------------------------
# RMSE : 14.9 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.17e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.16e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.17e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.49e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.55e-01
# NafionHP-conductivity-correction (0.5, 5) 4.14e+00
# NafionHP-conductivity-exp (1, 2) 1.37e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 3.56e-05
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.31e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.06e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.46e-09
# 3M-Deff-ratio (0.15, 0.6) 2.17e-01
# Nafion-memb-diff (1e-10, 1e-07) 4.27e-09
# i0-c (1e-05, 0.001) 3.40e-04
# elec-resistance (2e-06, 6e-06) 4.67e-06
# A_ch (0, 2) 4.00e-01
# B_ch (0, 2) 6.88e-01
# Kabs (1e-13, 1e-10) 2.11e-12
# wet-transition (0.1, 0.4) 3.29e-01
# kth-gdl (0.2, 33.333333333333336) 1.72e+01
# ------------------------------
# differential_evolution step 17: f(x)= 0.00019980054854221808
# ------------------------------
# RMSE : 14.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.24e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.18e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.47e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.09e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.02e-01
# NafionHP-conductivity-correction (0.5, 5) 4.47e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 3.38e-05
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.12e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.35e-09
# 3M-Deff-ratio (0.15, 0.6) 3.32e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.26e-08
# i0-c (1e-05, 0.001) 3.42e-04
# elec-resistance (2e-06, 6e-06) 4.58e-06
# A_ch (0, 2) 4.36e-01
# B_ch (0, 2) 9.66e-01
# Kabs (1e-13, 1e-10) 1.56e-12
# wet-transition (0.1, 0.4) 2.82e-01
# kth-gdl (0.2, 33.333333333333336) 1.78e+01
# ------------------------------
# differential_evolution step 18: f(x)= 0.00019980054854221808
# ------------------------------
# RMSE : 14.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.24e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.18e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.47e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.09e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.02e-01
# NafionHP-conductivity-correction (0.5, 5) 4.47e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 3.38e-05
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.12e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.35e-09
# 3M-Deff-ratio (0.15, 0.6) 3.32e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.26e-08
# i0-c (1e-05, 0.001) 3.42e-04
# elec-resistance (2e-06, 6e-06) 4.58e-06
# A_ch (0, 2) 4.36e-01
# B_ch (0, 2) 9.66e-01
# Kabs (1e-13, 1e-10) 1.56e-12
# wet-transition (0.1, 0.4) 2.82e-01
# kth-gdl (0.2, 33.333333333333336) 1.78e+01
# ------------------------------
# differential_evolution step 19: f(x)= 0.00016354439099964754
# ------------------------------
# RMSE : 12.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.26e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.32e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.00e-01
# NafionHP-conductivity-correction (0.5, 5) 4.43e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.61e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.17e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.87e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.32e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.36e-09
# i0-c (1e-05, 0.001) 3.37e-04
# elec-resistance (2e-06, 6e-06) 4.02e-06
# A_ch (0, 2) 4.18e-01
# B_ch (0, 2) 9.63e-01
# Kabs (1e-13, 1e-10) 1.56e-12
# wet-transition (0.1, 0.4) 3.70e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 20: f(x)= 0.0001626770404240058
# ------------------------------
# RMSE : 12.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.26e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.61e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 3.98e-01
# NafionHP-conductivity-correction (0.5, 5) 4.45e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.67e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.18e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 1.87e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.53e-09
# 3M-Deff-ratio (0.15, 0.6) 3.29e-01
# Nafion-memb-diff (1e-10, 1e-07) 2.37e-09
# i0-c (1e-05, 0.001) 3.66e-04
# elec-resistance (2e-06, 6e-06) 4.01e-06
# A_ch (0, 2) 4.38e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 3.70e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.78e+01
# ------------------------------
# differential_evolution step 21: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 22: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 23: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 24: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 25: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 26: f(x)= 0.00016067502990268286
# ------------------------------
# RMSE : 12.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.25e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.32e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.10e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.61e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.08e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.39e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.75e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.22e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.14e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.34e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.48e-08
# i0-c (1e-05, 0.001) 3.57e-04
# elec-resistance (2e-06, 6e-06) 4.03e-06
# A_ch (0, 2) 5.71e-01
# B_ch (0, 2) 9.60e-01
# Kabs (1e-13, 1e-10) 9.87e-13
# wet-transition (0.1, 0.4) 3.68e-01
# kth-gdl (0.2, 33.333333333333336) 1.77e+01
# ------------------------------
# differential_evolution step 27: f(x)= 0.0001463182331046309
# ------------------------------
# RMSE : 12.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.95e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.64e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.50e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.46e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.39e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.33e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.85e-09
# 3M-Deff-ratio (0.15, 0.6) 3.25e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.32e-08
# i0-c (1e-05, 0.001) 3.92e-04
# elec-resistance (2e-06, 6e-06) 4.26e-06
# A_ch (0, 2) 5.62e-01
# B_ch (0, 2) 9.56e-01
# Kabs (1e-13, 1e-10) 1.81e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.73e+01
# ------------------------------
# differential_evolution step 28: f(x)= 0.0001463182331046309
# ------------------------------
# RMSE : 12.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.95e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.64e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.50e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.46e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.39e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.33e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.85e-09
# 3M-Deff-ratio (0.15, 0.6) 3.25e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.32e-08
# i0-c (1e-05, 0.001) 3.92e-04
# elec-resistance (2e-06, 6e-06) 4.26e-06
# A_ch (0, 2) 5.62e-01
# B_ch (0, 2) 9.56e-01
# Kabs (1e-13, 1e-10) 1.81e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.73e+01
# ------------------------------
# differential_evolution step 29: f(x)= 0.0001463182331046309
# ------------------------------
# RMSE : 12.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.95e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.64e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.50e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.46e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.39e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.33e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.85e-09
# 3M-Deff-ratio (0.15, 0.6) 3.25e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.32e-08
# i0-c (1e-05, 0.001) 3.92e-04
# elec-resistance (2e-06, 6e-06) 4.26e-06
# A_ch (0, 2) 5.62e-01
# B_ch (0, 2) 9.56e-01
# Kabs (1e-13, 1e-10) 1.81e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.73e+01
# ------------------------------
# differential_evolution step 30: f(x)= 0.0001463182331046309
# ------------------------------
# RMSE : 12.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.95e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.64e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.50e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.46e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.39e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.33e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.85e-09
# 3M-Deff-ratio (0.15, 0.6) 3.25e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.32e-08
# i0-c (1e-05, 0.001) 3.92e-04
# elec-resistance (2e-06, 6e-06) 4.26e-06
# A_ch (0, 2) 5.62e-01
# B_ch (0, 2) 9.56e-01
# Kabs (1e-13, 1e-10) 1.81e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.73e+01
# ------------------------------
# differential_evolution step 31: f(x)= 0.0001463182331046309
# ------------------------------
# RMSE : 12.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.27e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.14e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 4.95e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.64e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.50e-01
# NafionHP-conductivity-correction (0.5, 5) 4.46e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 2.46e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 1.39e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.33e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.85e-09
# 3M-Deff-ratio (0.15, 0.6) 3.25e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.32e-08
# i0-c (1e-05, 0.001) 3.92e-04
# elec-resistance (2e-06, 6e-06) 4.26e-06
# A_ch (0, 2) 5.62e-01
# B_ch (0, 2) 9.56e-01
# Kabs (1e-13, 1e-10) 1.81e-12
# wet-transition (0.1, 0.4) 3.90e-01
# kth-gdl (0.2, 33.333333333333336) 1.73e+01
# ------------------------------
# differential_evolution step 32: f(x)= 0.000135384701600987
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.36e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.90e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.43e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.78e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.27e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.93e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.03e-08
# i0-c (1e-05, 0.001) 3.79e-04
# elec-resistance (2e-06, 6e-06) 4.44e-06
# A_ch (0, 2) 4.91e-01
# B_ch (0, 2) 9.68e-01
# Kabs (1e-13, 1e-10) 5.30e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.69e+01
# ------------------------------
# differential_evolution step 33: f(x)= 0.000135384701600987
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.36e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.90e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.43e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.78e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.27e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.93e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.03e-08
# i0-c (1e-05, 0.001) 3.79e-04
# elec-resistance (2e-06, 6e-06) 4.44e-06
# A_ch (0, 2) 4.91e-01
# B_ch (0, 2) 9.68e-01
# Kabs (1e-13, 1e-10) 5.30e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.69e+01
# ------------------------------
# differential_evolution step 34: f(x)= 0.000135384701600987
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.36e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.90e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.43e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.78e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.27e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.93e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.03e-08
# i0-c (1e-05, 0.001) 3.79e-04
# elec-resistance (2e-06, 6e-06) 4.44e-06
# A_ch (0, 2) 4.91e-01
# B_ch (0, 2) 9.68e-01
# Kabs (1e-13, 1e-10) 5.30e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.69e+01
# ------------------------------
# differential_evolution step 35: f(x)= 0.000135384701600987
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.13e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.36e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.90e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.39e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.43e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.78e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.56e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.27e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.93e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.03e-08
# i0-c (1e-05, 0.001) 3.79e-04
# elec-resistance (2e-06, 6e-06) 4.44e-06
# A_ch (0, 2) 4.91e-01
# B_ch (0, 2) 9.68e-01
# Kabs (1e-13, 1e-10) 5.30e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.69e+01
# ------------------------------
# differential_evolution step 36: f(x)= 0.0001336866275938487
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.37e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.55e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.32e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.33e-01
# NafionHP-conductivity-correction (0.5, 5) 4.47e+00
# NafionHP-conductivity-exp (1, 2) 1.42e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.64e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.49e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.25e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.88e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 9.53e-09
# i0-c (1e-05, 0.001) 3.82e-04
# elec-resistance (2e-06, 6e-06) 4.48e-06
# A_ch (0, 2) 4.78e-01
# B_ch (0, 2) 9.67e-01
# Kabs (1e-13, 1e-10) 2.15e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.68e+01
# ------------------------------
# differential_evolution step 37: f(x)= 0.0001336866275938487
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.37e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.55e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.32e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.33e-01
# NafionHP-conductivity-correction (0.5, 5) 4.47e+00
# NafionHP-conductivity-exp (1, 2) 1.42e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.64e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.49e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.25e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.88e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 9.53e-09
# i0-c (1e-05, 0.001) 3.82e-04
# elec-resistance (2e-06, 6e-06) 4.48e-06
# A_ch (0, 2) 4.78e-01
# B_ch (0, 2) 9.67e-01
# Kabs (1e-13, 1e-10) 2.15e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.68e+01
# ------------------------------
# differential_evolution step 38: f(x)= 0.0001336866275938487
# ------------------------------
# RMSE : 11.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.15e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.37e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.55e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.32e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.33e-01
# NafionHP-conductivity-correction (0.5, 5) 4.47e+00
# NafionHP-conductivity-exp (1, 2) 1.42e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.64e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.49e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.25e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.88e-09
# 3M-Deff-ratio (0.15, 0.6) 3.19e-01
# Nafion-memb-diff (1e-10, 1e-07) 9.53e-09
# i0-c (1e-05, 0.001) 3.82e-04
# elec-resistance (2e-06, 6e-06) 4.48e-06
# A_ch (0, 2) 4.78e-01
# B_ch (0, 2) 9.67e-01
# Kabs (1e-13, 1e-10) 2.15e-12
# wet-transition (0.1, 0.4) 3.96e-01
# kth-gdl (0.2, 33.333333333333336) 1.68e+01
# ------------------------------
# differential_evolution step 39: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 40: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 41: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 42: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 43: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 44: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 45: f(x)= 0.0001307265168816721
# ------------------------------
# RMSE : 11.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.29e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.19e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.38e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.82e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.60e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.44e+00
# NafionHP-conductivity-exp (1, 2) 1.43e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.59e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 2.76e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.15e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.29e-08
# i0-c (1e-05, 0.001) 3.65e-04
# elec-resistance (2e-06, 6e-06) 4.70e-06
# A_ch (0, 2) 4.05e-01
# B_ch (0, 2) 9.74e-01
# Kabs (1e-13, 1e-10) 6.25e-12
# wet-transition (0.1, 0.4) 3.86e-01
# kth-gdl (0.2, 33.333333333333336) 1.62e+01
# ------------------------------
# differential_evolution step 46: f(x)= 0.0001279027885535487
# ------------------------------
# RMSE : 11.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.12e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.39e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.09e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.55e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.53e-01
# NafionHP-conductivity-correction (0.5, 5) 4.35e+00
# NafionHP-conductivity-exp (1, 2) 1.44e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.63e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 4.48e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.74e-09
# 3M-Deff-ratio (0.15, 0.6) 3.18e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.09e-08
# i0-c (1e-05, 0.001) 3.66e-04
# elec-resistance (2e-06, 6e-06) 4.55e-06
# A_ch (0, 2) 4.34e-01
# B_ch (0, 2) 9.73e-01
# Kabs (1e-13, 1e-10) 4.38e-12
# wet-transition (0.1, 0.4) 3.76e-01
# kth-gdl (0.2, 33.333333333333336) 1.61e+01
# ------------------------------
# differential_evolution step 47: f(x)= 0.0001279027885535487
# ------------------------------
# RMSE : 11.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.12e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.39e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.09e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.55e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.53e-01
# NafionHP-conductivity-correction (0.5, 5) 4.35e+00
# NafionHP-conductivity-exp (1, 2) 1.44e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.63e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 4.48e-04
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.26e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.74e-09
# 3M-Deff-ratio (0.15, 0.6) 3.18e-01
# Nafion-memb-diff (1e-10, 1e-07) 1.09e-08
# i0-c (1e-05, 0.001) 3.66e-04
# elec-resistance (2e-06, 6e-06) 4.55e-06
# A_ch (0, 2) 4.34e-01
# B_ch (0, 2) 9.73e-01
# Kabs (1e-13, 1e-10) 4.38e-12
# wet-transition (0.1, 0.4) 3.76e-01
# kth-gdl (0.2, 33.333333333333336) 1.61e+01
# ------------------------------
# differential_evolution step 48: f(x)= 0.0001279027885535487
# ------------------------------
# RMSE : 11.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.28e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.12e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.39e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 3.09e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.55e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 4.53e-01
# NafionHP-conductivity-correction (0.5, 5) 4.35e+00
# NafionHP-conductivity-exp (1, 2) 1.44e+00
# ...
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 150: f(x)= 0.00010522274741001737
# ------------------------------
# RMSE : 10.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.37e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.39e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.48e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.60e-01
# NafionHP-conductivity-correction (0.5, 5) 4.06e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.60e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 7.50e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.37e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.70e-09
# 3M-Deff-ratio (0.15, 0.6) 3.42e-01
# Nafion-memb-diff (1e-10, 1e-07) 8.22e-08
# i0-c (1e-05, 0.001) 4.21e-04
# elec-resistance (2e-06, 6e-06) 4.77e-06
# A_ch (0, 2) 2.56e-02
# B_ch (0, 2) 1.21e+00
# Kabs (1e-13, 1e-10) 9.68e-13
# wet-transition (0.1, 0.4) 3.04e-01
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 151: f(x)= 0.00010518705931592307
# ------------------------------
# RMSE : 10.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.35e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.08e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.39e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.23e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.75e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.63e-01
# NafionHP-conductivity-correction (0.5, 5) 4.17e+00
# NafionHP-conductivity-exp (1, 2) 1.47e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.63e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 8.33e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.36e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.80e-09
# 3M-Deff-ratio (0.15, 0.6) 3.43e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.69e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.79e-06
# A_ch (0, 2) 1.14e-02
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.02e-12
# wet-transition (0.1, 0.4) 3.08e-01
# kth-gdl (0.2, 33.333333333333336) 1.55e+01
# ------------------------------
# differential_evolution step 152: f(x)= 0.00010509437960054283
# ------------------------------
# RMSE : 10.3 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.07e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.17e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.67e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.69e-01
# NafionHP-conductivity-correction (0.5, 5) 4.02e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.65e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 8.60e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.36e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.89e-09
# 3M-Deff-ratio (0.15, 0.6) 3.43e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.62e-08
# i0-c (1e-05, 0.001) 4.25e-04
# elec-resistance (2e-06, 6e-06) 4.84e-06
# A_ch (0, 2) 8.07e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.35e-12
# wet-transition (0.1, 0.4) 3.12e-01
# kth-gdl (0.2, 33.333333333333336) 1.54e+01
# ------------------------------
# differential_evolution step 153: f(x)= 0.00010470933619666226
# ------------------------------
# RMSE : 10.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.20e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.52e-01
# NafionHP-conductivity-correction (0.5, 5) 3.96e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.57e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 9.82e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.39e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.44e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.90e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.80e-06
# A_ch (0, 2) 5.02e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.28e-12
# wet-transition (0.1, 0.4) 2.99e-01
# kth-gdl (0.2, 33.333333333333336) 1.53e+01
# ------------------------------
# differential_evolution step 154: f(x)= 0.00010470933619666226
# ------------------------------
# RMSE : 10.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.20e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.52e-01
# NafionHP-conductivity-correction (0.5, 5) 3.96e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.57e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 9.82e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.39e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.44e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.90e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.80e-06
# A_ch (0, 2) 5.02e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.28e-12
# wet-transition (0.1, 0.4) 2.99e-01
# kth-gdl (0.2, 33.333333333333336) 1.53e+01
# ------------------------------
# differential_evolution step 155: f(x)= 0.00010470933619666226
# ------------------------------
# RMSE : 10.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.20e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.52e-01
# NafionHP-conductivity-correction (0.5, 5) 3.96e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.57e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 9.82e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.39e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.44e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.90e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.80e-06
# A_ch (0, 2) 5.02e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.28e-12
# wet-transition (0.1, 0.4) 2.99e-01
# kth-gdl (0.2, 33.333333333333336) 1.53e+01
# ------------------------------
# differential_evolution step 156: f(x)= 0.00010470933619666226
# ------------------------------
# RMSE : 10.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.20e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.52e-01
# NafionHP-conductivity-correction (0.5, 5) 3.96e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.57e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 9.82e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.39e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.44e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.90e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.80e-06
# A_ch (0, 2) 5.02e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.28e-12
# wet-transition (0.1, 0.4) 2.99e-01
# kth-gdl (0.2, 33.333333333333336) 1.53e+01
# ------------------------------
# differential_evolution step 157: f(x)= 0.00010470933619666226
# ------------------------------
# RMSE : 10.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.33e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.09e+02
# AquivionD83-06-cl-proton-cond-exp (2, 4) 3.40e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 2.20e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 1.76e-07
# AquivionD83-06-cl-o2-diff-exp (0.2, 2) 2.52e-01
# NafionHP-conductivity-correction (0.5, 5) 3.96e+00
# NafionHP-conductivity-exp (1, 2) 1.46e+00
# Nafion-memb-abs-constant (1e-06, 0.01) 1.57e-04
# Aquivion-memb-abs-constant (1e-06, 0.01) 9.82e-03
# NafionLQ1115-o2-diff (1e-12, 1e-08) 2.39e-09
# AquivionD83-06-o2-diff (1e-12, 1e-08) 3.87e-09
# 3M-Deff-ratio (0.15, 0.6) 3.44e-01
# Nafion-memb-diff (1e-10, 1e-07) 7.90e-08
# i0-c (1e-05, 0.001) 4.23e-04
# elec-resistance (2e-06, 6e-06) 4.80e-06
# A_ch (0, 2) 5.02e-03
# B_ch (0, 2) 1.22e+00
# Kabs (1e-13, 1e-10) 1.28e-12
# wet-transition (0.1, 0.4) 2.99e-01
# kth-gdl (0.2, 33.333333333333336) 1.53e+01
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sol, p_est = model.estimate(exp_res_list, t=0, print_iterations=True, popsize=40, ftol=1e-5)
#       2 model.p.update({param: v for param, v in zip(model.p_i_name, p_est)})
#
# File ~/Documents/Development/coulomb/src/coulomb/estimation.py:78, in ParameterEstimation.estimate(self, y_exp, t, u, x0, p, print_iterations, popsize, workers, ftol, atol)
#      75     if intermediate_result.fun < ftol:
#      76         return True
# ---> 78 sol = differential_evolution(f, tuple(([0,1] for p in self.unknown_p_list)), disp=True,
#      79                              callback=print_res if print_iterations else None,
#      80                              popsize=popsize, polish=False, workers=workers,
#      81                              mutation=(0,1.6), seed=2, init='sobol',
#      82                              atol=atol)
#      83 return sol, self.theta_to_p(sol.x)
#
# File ~/.conda/envs/coulomb/lib/python3.12/site-packages/scipy/_lib/_util.py:440, in _transition_to_rng.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     433     message = (
#     434         "The NumPy global RNG was seeded by calling "
#     435         f"`np.random.seed`. Beginning in {end_version}, this "
#     436         "function will no longer use the global RNG."
#     437     ) + cmn_msg
#     438     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 440 return fun(*args, **kwargs)
#
# File ~/.conda/envs/coulomb/lib/python3.12/site-packages/scipy/optimize/_differentialevolution.py:501, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, rng, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     484 # using a context manager means that any created Pool objects are
#     485 # cleared up.
#     486 with DifferentialEvolutionSolver(func, bounds, args=args,
#     487                                  strategy=strategy,
#     488                                  maxiter=maxiter,
#    (...)
#     499                                  integrality=integrality,
#     500                                  vectorized=vectorized) as solver:
# --> 501     ret = solver.solve()
#     503 return ret
#
# File ~/.conda/envs/coulomb/lib/python3.12/site-packages/scipy/optimize/_differentialevolution.py:1185, in DifferentialEvolutionSolver.solve(self)
#    1182 for nit in range(1, self.maxiter + 1):
#    1183     # evolve the population by a generation
#    1184     try:
# -> 1185         next(self)
#    1186     except StopIteration:
#    1187         warning_flag = True
#
# File ~/.conda/envs/coulomb/lib/python3.12/site-packages/scipy/optimize/_differentialevolution.py:1600, in DifferentialEvolutionSolver.__next__(self)
#    1598     feasible = True
#    1599     cv = np.atleast_2d([0.])
# -> 1600     energy = self.func(parameters)
#    1601     self._nfev += 1
#    1603 # compare trial and population member
#
# File ~/.conda/envs/coulomb/lib/python3.12/site-packages/scipy/_lib/_util.py:657, in _FunctionWrapper.__call__(self, x)
#     656 def __call__(self, x):
# --> 657     return self.f(x, *self.args)
#
# File ~/Documents/Development/coulomb/src/coulomb/estimation.py:65, in ParameterEstimation.estimate.<locals>.f(x)
#      63 px = p.copy()
#      64 px.update({p[0]: v for p, v in zip(self.unknown_p_list, self.theta_to_p(x))})
# ---> 65 res = self.residuals(y_exp, t, u, x0, px)
#      66 return np.dot(res, res) / len(res)
#
# File ~/Documents/Development/coulomb/src/coulomb/estimation.py:53, in ParameterEstimation.residuals(self, y_exp, t, u, x0, p)
#      52 def residuals(self, y_exp, t, u=None, x0=None, p=None):
# ---> 53     t, x, y = self.solve(t, u, x0, p)
#      54     return y_exp - y
#
# File ~/Documents/Development/coulomb/src/coulomb/estimation.py:210, in ParameterEstimationSteadyState.solve(self, time, u, x0, parameters_dict)
#     208 def solve(self, time, u=None, x0=None, parameters_dict=None):
#     209     parameters_dict = parameters_dict if parameters_dict else self.p
# --> 210     y = self.h(parameters_dict)
#     211     return 0, 0, y
#
# Cell In[5], line 16, in h2(params)
#      14 for cell in cells:
#      15     if case in exp_data[exp_data.cell_id == cell].case.unique():
# ---> 16         V_sim = compute_ui_curve(fuel_cells[cell], case)
#      17         hfr_sim = 1e4*fuel_cells[cell].high_frequency_resistance() * (1-np.isnan(exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'hfr']))
#      18         res_list += [V_sim, hfr_sim]
#
# Cell In[2], line 33, in compute_ui_curve(cell, case)
#      29  cell.calculate_water_transport()
#      30  # s_ca_cl = fuel_cell.ca.cl.water_saturation
#      31  # fuel_cell.membrane.water_content = fuel_cell.membrane.water_content * (1-s_ca_cl) + s_ca_cl * 22
#      32  # fuel_cell.ca.cl.water_content = fuel_cell.ca.cl.water_content * (1-s_ca_cl) + s_ca_cl * 22
# ---> 33  cell.calculate_reactant_concentration_at_cl()
#      35 # fuel_cell.solve_transport()
#      36  return cell.cell_voltage()
#
# File ~/Documents/Development/coulomb/src/coulomb/fuelcell.py:169, in FuelCell.calculate_reactant_concentration_at_cl(self)
#     164 ca.cl.gas.X[...,species_indexes['o2']] = np.maximum(1e-12,
#     165     ca.ch.gas.X[...,species_indexes['o2']] * ca.ch.gas.concentration() -
#     166     self.o2_consumption * ca.o2_transport_resistance) / ca.cl.gas.concentration()
#     168 an = self.an
# --> 169 an.h2_transport_resistance = an.calculate_gas_transport_resistance('h2')
#     170 an.cl.gas.X[...,species_indexes['h2']] = np.maximum(1e-12,
#     171     an.ch.gas.X[...,species_indexes['h2']] * an.ch.gas.concentration() -
#     172     self.h2_consumption * an.h2_transport_resistance) / an.cl.gas.concentration()
#     174 for side in (self.ca, self.an):
#
# File ~/Documents/Development/coulomb/src/coulomb/fuelcell.py:48, in FuelCellSide.calculate_gas_transport_resistance(self, species, ionomer_water_content)
#      47 def calculate_gas_transport_resistance(self, species, ionomer_water_content=11):
# ---> 48     return (sum(layer.calculate_gas_transport_resistance(species) for layer in self.porous_layers) +
#      49             self.ch.calculate_gas_transport_resistance(species) +
#      50             (self.cl.calculate_o2_film_resistance(ionomer_water_content, self.cl.temperature) if species == 'o2' else 0))
#
# File ~/Documents/Development/coulomb/src/coulomb/fuelcell.py:48, in <genexpr>(.0)
#      47 def calculate_gas_transport_resistance(self, species, ionomer_water_content=11):
# ---> 48     return (sum(layer.calculate_gas_transport_resistance(species) for layer in self.porous_layers) +
#      49             self.ch.calculate_gas_transport_resistance(species) +
#      50             (self.cl.calculate_o2_film_resistance(ionomer_water_content, self.cl.temperature) if species == 'o2' else 0))
#
# File ~/Documents/Development/coulomb/src/coulomb/porous_layers.py:101, in PorousLayer.calculate_gas_transport_resistance(self, species)
#      96 def calculate_gas_transport_resistance(self, species='o2'):
#      97     return self.transport_resistance_model.total_diffusion_resistance(
#      98         self,
#      99         self.temperature,
#     100         self.get_species_diffusion_coefficient(species),
# --> 101         self.get_species_molecular_weight(species),
#     102         self.water_saturation)
#
# File ~/Documents/Development/coulomb/src/coulomb/porous_layers.py:48, in PorousLayer.get_species_molecular_weight(self, species)
#      45 def get_species_diffusion_coefficient(self, species):
#      46     return self.gas.species_diffusion_coefficient(species)
# ---> 48 def get_species_molecular_weight(self, species):
#      49     return self.gas.molecular_weights[species_indexes[species]]
#      51 def get_gas_temperature(self):
#
# KeyboardInterrupt:

# %%
'''------------------------------
differential_evolution step 193: f(x)= 3.98489192715642e-05
------------------------------
RMSE : 6.3 mV
AquivionD83-06-cl-proton-cond (1, 200) 1.20e+00
NafionLQ1115-cl-proton-cond (1, 200) 2.06e+00
AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
AquivionD83-06-pore-diameter (1e-08, 2e-07) 3.62e-08
NafionLQ1115-pore-diameter (1e-08, 2e-07) 1.97e-07
AquivionD83-06-cl-o2-diff-exp (0.5, 2) 8.54e-01
NafionLQ1115-cl-o2-diff-exp (0.5, 2) 5.00e-01
NafionHP-conductivity-exp (1, 2) 1.15e+00
Nafion-memb-abs-constant (1e-06, 0.0001) 1.25e-06
Aquivion-memb-abs-constant (1e-06, 0.0001) 2.91e-06
NafionLQ1115-o2-diff (1e-12, 1e-09) 9.93e-10
AquivionD83-06-o2-diff (1e-12, 1e-08) 1.34e-09
3M-Deff-ratio (0.15, 0.5) 3.71e-01
Nafion-memb-diff (1e-10, 1e-09) 1.19e-10
elec-resistance (2e-06, 6e-06) 4.58e-06
A_ch (0.1, 2) 1.04e-01
B_ch (0.0001, 2) 7.68e-01
Kabs (1e-13, 1e-11) 2.98e-13
Aquivion-cl-K-abs (1e-14, 1e-11) 1.35e-14
Nafion-cl-K-abs (1e-14, 1e-11) 3.08e-14
wet-transition (0.0, 0.4) 2.65e-01
kth-gdl (0.03, 5) 1.80e+00
------------------------------'''
# Out:
# '------------------------------\ndifferential_evolution step 193: f(x)= 3.98489192715642e-05\n------------------------------\nRMSE : 6.3 mV\nAquivionD83-06-cl-proton-cond (1, 200) 1.20e+00\nNafionLQ1115-cl-proton-cond (1, 200) 2.06e+00\nAquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00\nNafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00\nAquivionD83-06-pore-diameter (1e-08, 2e-07) 3.62e-08\nNafionLQ1115-pore-diameter (1e-08, 2e-07) 1.97e-07\nAquivionD83-06-cl-o2-diff-exp (0.5, 2) 8.54e-01\nNafionLQ1115-cl-o2-diff-exp (0.5, 2) 5.00e-01\nNafionHP-conductivity-exp (1, 2) 1.15e+00\nNafion-memb-abs-constant (1e-06, 0.0001) 1.25e-06\nAquivion-memb-abs-constant (1e-06, 0.0001) 2.91e-06\nNafionLQ1115-o2-diff (1e-12, 1e-09) 9.93e-10\nAquivionD83-06-o2-diff (1e-12, 1e-08) 1.34e-09\n3M-Deff-ratio (0.15, 0.5) 3.71e-01\nNafion-memb-diff (1e-10, 1e-09) 1.19e-10\nelec-resistance (2e-06, 6e-06) 4.58e-06\nA_ch (0.1, 2) 1.04e-01\nB_ch (0.0001, 2) 7.68e-01\nKabs (1e-13, 1e-11) 2.98e-13\nAquivion-cl-K-abs (1e-14, 1e-11) 1.35e-14\nNafion-cl-K-abs (1e-14, 1e-11) 3.08e-14\nwet-transition (0.0, 0.4) 2.65e-01\nkth-gdl (0.03, 5) 1.80e+00\n------------------------------'

# %%
exp_data = pd.read_csv(f'../data/garsany_et_al_2018/Garsany2018-gz.csv', sep=';', decimal=',')
exp_data = exp_data[exp_data.cell_id != 'GORE']
cells = exp_data.cell_id.unique()
for cell in cells: 
    exp_data.loc[exp_data.cell_id  == cell, 'case'] = exp_data.loc[exp_data.cell_id  == cell, ['T_stack', 'rh_ca', 'rh_an', 'p_ca_out']].sum(axis=1)
case_list = [1,2,3]
exp_data['case'] = exp_data['case'].map(dict(zip(exp_data['case'].unique(),case_list)))
exp_data = exp_data

# %%
case_name = [
    
    'Nafion LSC - 1 bar - 50% RH', 
    'Nafion LSC - 1 bar - 100% RH', 
    'Nafion LSC - 1.5 bar - 100% RH', 
    'Aquivion SSC - 1 bar - 50% RH', 
    'Aquivion SSC - 1 bar - 100% RH', 
    
    'Aquivion SSC - 1.5 bar - 100% RH', 
   
]
labels = []
fig1, ax1 = plt.subplots(1, figsize=(6,3))
fig2, ax2 = plt.subplots(1,1, figsize=(6,3))
for i_cell, cell in enumerate(['LSC Nafion', 'SSC Aquivion']): 
    for k, case in enumerate(case_list): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]
        U_exp = case_exp_data['U'].values
        res = U_exp - U_sim
        RMSE = np.sqrt(np.dot(res, res) / len(res)) * 1000
        
        l2, = ax1.plot(fuel_cell.current_density/1e4, U_exp, 'C{}'.format(k) + ('s' if i_cell == 1 else 'o'))
        l, = ax1.plot(fuel_cell.current_density/1e4, U_sim, 'C{}-'.format(k) + ('-' if i_cell == 1 else ''), label='{:.0f} mV'.format(RMSE))
        labels.append(l)
        leg_RMSE = ax1.legend(title='RMSE', bbox_to_anchor=(1.5,1), loc='upper left')
       
        ax2.plot(fuel_cell.current_density/1e4, 1e7*fuel_cell.high_frequency_resistance(), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        ax2.plot(case_exp_data['i'].values, 1e7*case_exp_data['hfr'].values, 'C{}'.format(k) + ('s' if i_cell == 1 else 'o'))
        
        plt.figure(3)
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.bi, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.bi, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.pe, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )

plt.figure(1)
leg1 = plt.legend(handles=labels[0:3], labels=['1.0 bar - 50% RH', '1.0 bar - 100% RH', '1.5 bar - 100% RH', ], bbox_to_anchor=(1.04,1), loc='upper left')
leg2 = plt.legend(handles=(labels[0], labels[3]), labels=['Nafion LSC', 'Aquivion SSC'], bbox_to_anchor=(1.04,0.6), loc='upper left')
leg3 = plt.legend(handles=(l, l2), labels=['Sim.', 'Exp.'], bbox_to_anchor=(1.04,0.3), loc='upper left')
ax1.add_artist(leg_RMSE)
ax1.add_artist(leg1)
ax1.add_artist(leg2)
ax1.set_xlabel('Current density (A/cm$^2$)')
ax1.set_ylabel('Cell voltage (V)')
fig1.tight_layout()
fig1.savefig('./test_figure.png', bbox_extra_artists=(leg1,leg_RMSE), bbox_inches='tight')

# %%
for i_cell, cell in enumerate(['LSC Nafion']): 
    for k, case in enumerate([1,2,3]): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]
        U_exp = case_exp_data['U'].values
        res = U_exp - U_sim
        RMSE = np.sqrt(np.dot(res, res) / len(res)) * 1000
        
        plt.figure(1)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.water_content)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.equiv_water_content)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.equiv_water_content)
        
        plt.figure(3)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.gdl.water_saturation)
        plt.figure(2)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.high_frequency_resistance())
        #plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.bi, 'C1-' + '-' if i_cell == 1 else '', label=case, alpha=1 )
       # plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.pe, 'C2-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=1 )
