# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataclasses import dataclass, field
import coulomb as cb
    
exp_data = pd.read_csv(f'../data/garsany_et_al_2018/Garsany2018-gz.csv', sep=';', decimal=',')
exp_data = exp_data[exp_data.cell_id != 'GORE']
cells = exp_data.cell_id.unique()
for cell in cells: 
    exp_data.loc[exp_data.cell_id  == cell, 'case'] = exp_data.loc[exp_data.cell_id  == cell, ['T_stack', 'rh_ca', 'rh_an', 'p_ca_out']].sum(axis=1)
case_list = [1,2,3]
exp_data['case'] = exp_data['case'].map(dict(zip(exp_data['case'].unique(),case_list)))
exp_data
# Out:
#          i       U  T_stack  rh_ca  rh_an       st_ca       st_an  x_o2_ca  \
# 0   0.0113  0.9005   353.15    1.0    1.0  100.884956  100.884956      0.2
# 1   0.0198  0.8797   353.15    1.0    1.0   57.575758   57.575758      0.2
# 2   0.0594  0.8499   353.15    1.0    1.0   19.191919   19.191919      0.2
# 3   0.1876  0.8012   353.15    1.0    1.0    6.076759    6.076759      0.2
# 4   0.4047  0.7396   353.15    1.0    1.0    2.816901    2.816901      0.2
# ..     ...     ...      ...    ...    ...         ...         ...      ...
# 91  1.6031  0.6016   353.15    1.0    1.0    2.000000    2.000000      0.2
# 92  1.8349  0.5505   353.15    1.0    1.0    2.000000    2.000000      0.2
# 93  2.0216  0.5006   353.15    1.0    1.0    2.000000    2.000000      0.2
# 94  2.1860  0.4510   353.15    1.0    1.0    2.000000    2.000000      0.2
# 95  2.3302  0.4013   353.15    1.0    1.0    2.000000    2.000000      0.2
#
#     p_ca_out  p_an_out figure       cell_id       hfr  case
# 0     101000    101000     7a    LSC Nafion       NaN     1
# 1     101000    101000     7a    LSC Nafion       NaN     1
# 2     101000    101000     7a    LSC Nafion       NaN     1
# 3     101000    101000     7a    LSC Nafion  0.000006     1
# 4     101000    101000     7a    LSC Nafion  0.000006     1
# ..       ...       ...    ...           ...       ...   ...
# 91    150000    150000     8a  SSC Aquivion  0.000005     3
# 92    150000    150000     8a  SSC Aquivion  0.000005     3
# 93    150000    150000     8a  SSC Aquivion  0.000006     3
# 94    150000    150000     8a  SSC Aquivion  0.000006     3
# 95    150000    150000     8a  SSC Aquivion  0.000006     3
#
# [72 rows x 14 columns]

# %%
def compute_ui_curve(cell, case): 
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell.name)]
        current_density = np.maximum(1,1e4*case_exp_data['i'].values)
        cathode_conditions = cb.OperatingConditions(
            inlet_temperature = case_exp_data['T_stack'].values,
            inlet_relative_humidity=case_exp_data['rh_ca'].values,
            outlet_pressure=case_exp_data['p_ca_out'].values,
            dry_o2_mole_fraction=0.21,
            dry_h2_mole_fraction=0,
            stoichiometry=case_exp_data['st_ca'].values,
        )
        anode_conditions = cb.OperatingConditions(
            inlet_temperature = case_exp_data['T_stack'].values,
            inlet_relative_humidity=case_exp_data['rh_an'].values,
            outlet_pressure=case_exp_data['p_an_out'].values,
            dry_o2_mole_fraction=0,
            dry_h2_mole_fraction=1,
            stoichiometry=case_exp_data['st_an'].values,
        )

        cell.set_conditions(case_exp_data['T_stack'].values, 
                                 current_density,cathode_conditions, anode_conditions)
        dT = 10
        temperature_increase = 0
        for i in range(3):
            cell.ca.gdl.water_saturation=0
            cell.calculate_water_transport()
            cell.calculate_reactant_concentration_at_cl()
            cell.calculate_heat_transfer_resistance()
            mea_temperature = fuel_cell.temperature + temperature_increase 
            cell.set_mea_temperature(mea_temperature)
            V_cell = cell.cell_voltage()
            temperature_increase = (cell.current_density *np.maximum(1.44 - V_cell, 1.2)) * cell.thermal_resistance
           
        
            
            
        
       # fuel_cell.solve_transport() 
        return V_cell

# %%
class HydrogenPermeationModel:
    def __init__(self): 
        pass 

    def permeation_flux(self,
                        membrane_thickness: float,
                        partial_pressure_h2: float,
                        temperature: float,
                        pressure_difference: float,
                        water_vol_fraction: float
        ) -> float:
        D_h2_w = 2.205e-9
        S_h2_w = 7.12e-6
        k_l_mb = 1.6e-18
        mu_w = cb.water.water_dynamic_viscosity(temperature)
        h2_permeability = (D_h2_w + water_vol_fraction * k_l_mb / mu_w * pressure_difference) * S_h2_w
        return h2_permeability * 1e-3 * partial_pressure_h2 / membrane_thickness
    
class ChannelGasResistanceModel: 
    def __init__(self, A_cell): 
        self.A_cell = A_cell

    def total_resistance(self, channel, diffusion_coefficient, volume_flow_rate): 
        return self.A_cell / volume_flow_rate / 2


@dataclass 
class CatalystLayerIonomerModel: 
    density: float = 2004 
    equivalent_weight: float = 952. 
    hydrated_proton_conductivity: float = 11 # S/m
    proton_conductivity_exponent: float = 2.7

    def o2_film_resistance(self, water_content, temperature= 353.15):
        # Linear regression of data from Jinnouchi et al. (2021), neglecting bulk diffusion.
        # Activation energy obtained by Kudo et al. (2006).
        return 1.14698e-10 * (water_content/14) ** 0.708 #* cb.calculate_arrhenius_term(-24e6, temperature, 353.15)

    def proton_conductivity(self, relative_humidity, water_content, temperature):
        return self.hydrated_proton_conductivity * (water_content/14.) ** (self.proton_conductivity_exponent) * cb.calculate_arrhenius_term(11e6, temperature, 353.15) # Following measurements of Hutapea et al. (2023)

@dataclass
class PorousLiquidTransportModel: 
    critical_damkholer: float = 1.
    dry_wet_transition_parameter: float = 10

    def vapor_transport_resistance(self, cell_side): 
        return cell_side.calculate_gas_transport_resistance('h2o')
    
    def calculate_damkholer_number(self, cell_side, water_injection_flux): 
        cl_sat_concentration = cell_side.cl.get_saturation_concentration()
        ch_vapor_concentration = cell_side.ch.get_vapor_concentration()
        max_vapor_removal_flux = (cl_sat_concentration - ch_vapor_concentration) / cell_side.h2ov_transport_resistance
        return water_injection_flux / max_vapor_removal_flux
        
    def calculate_water_saturation(self, cell_side, water_injection_flux): 
        #damkholer = self.calculate_damkholer_number(cell_side, water_injection_flux)
        cl_sat_concentration = cell_side.cl.get_saturation_concentration()
        ch_vapor_concentration = cell_side.ch.get_vapor_concentration()
        max_vapor_removal_flux = (cl_sat_concentration - ch_vapor_concentration) / cell_side.h2ov_transport_resistance
        #return self.wet_saturation *  cb.sigmoid(water_injection_flux, max_vapor_removal_flux * self.critical_damkholer, self.dry_wet_transition_parameter)
        return (np.maximum(water_injection_flux-max_vapor_removal_flux * self.critical_damkholer,1e-12) / cell_side.gdl.absolute_permeability) ** self.dry_wet_transition_parameter

# %%
def create_fuel_cell(params, cell): 

    ORRkinetics=cb.ElectrochemicalReaction(
                    reference_exchange_current_density=params['i0-c'],
                    reaction_order=params['gamma-c'], 
                    activation_energy=67e6, 
                    reference_activity=1.01325e5,
                    reference_temperature=353.15,
                    number_of_electrons=2,
                    charge_transfer_coeff=0.5
                )
    
    IonomerAquivionD83=cb.CatalystLayerIonomerModel(equivalent_weight=830.,
        hydrated_proton_conductivity=params['AquivionD83-06-cl-proton-cond'],
        proton_conductivity_rh_exponent=0, 
        proton_conductivity_water_content_exponent=params['AquivionD83-06-cl-proton-cond-exp'],
        hydrated_o2_diffusion=params['AquivionD83-06-o2-diff'],
        o2_diffusion_exponent=params['AquivionD83-06-cl-o2-diff-exp'])
    
    IonomerNafionLQ1115=cb.CatalystLayerIonomerModel(equivalent_weight=1100.,
        hydrated_proton_conductivity=params['NafionLQ1115-cl-proton-cond'],
        proton_conductivity_rh_exponent=0,
        proton_conductivity_water_content_exponent=params['NafionLQ1115-cl-proton-cond-exp'], 
        hydrated_o2_diffusion=params['NafionLQ1115-o2-diff'], 
        o2_diffusion_exponent=params['NafionLQ1115-cl-o2-diff-exp'])

    AquivionCL = cb.CatalystLayer(
        platinum_loading=0.31e-2, 
        thickness=8e-6, 
        ionomer=IonomerAquivionD83,
        reaction=ORRkinetics,
        ecsa=61e3, 
        ionomer_to_carbon_ratio=0.95,
        pore_diameter=params['AquivionD83-06-pore-diameter'],
        catalyst_platinum_weight_percent=0.5, 
        thermal_conductivity=0.25, 
        absolute_permeability=params['Aquivion-cl-K-abs'],
        contact_angle=95.,
        omega_PtO=0) 

    NafionCL = cb.CatalystLayer(
        platinum_loading=0.31e-2, 
        thickness=7.8e-6, 
        ionomer=IonomerNafionLQ1115,
        reaction=ORRkinetics,
        ecsa=65e3, 
        ionomer_to_carbon_ratio=0.95,
        pore_diameter=params['NafionLQ1115-pore-diameter'],
        catalyst_platinum_weight_percent=0.5, 
        absolute_permeability=params['Nafion-cl-K-abs'],
        contact_angle=95.,
        omega_PtO=0) 

    GDL3Mca = cb.PorousLayer(
        thickness=236e-6,
        effective_gas_diffusion_ratio=params['3M-Deff-ratio'], 
        absolute_permeability=params['Kabs'], 
        thermal_conductivity=params['kth-gdl'],
        porosity=0.3,
        contact_angle=120.)

    GDL3Man = cb.PorousLayer(
        thickness=266e-6,
        effective_gas_diffusion_ratio=params['3M-Deff-ratio'],
        thermal_conductivity=params['kth-gdl'],
        absolute_permeability=params['Kabs'], 
        porosity=0.6,
        contact_angle=120.) 
    
    NafionHP = cb.Membrane(
        dry_thickness=20.3e-6, 
        conductivity_correction=params['NafionHP-conductivity-correction'],
        conductivity_exp=params['NafionHP-conductivity-exp'],
        water_balance_model=cb.MembraneWaterBalanceModel(reference_absorption_coefficient=params['Nafion-memb-abs-constant'] if cell=='LSC Nafion' else params['Aquivion-memb-abs-constant'])
    )
    fc = cb.FuelCell(
        electrical_resistance=params['elec-resistance'],
        cell_area = 10e-4, 
        cell_number = 1, 
        ca = cb.FuelCellSide(
            cl=NafionCL if cell=='LSC Nafion' else AquivionCL, has_mpl=False, gdl=GDL3Mca,  
            ch=cb.GasFlowChannel(
                reactant='o2',
                height=1e-3, 
                length=10e-4/2e-3,
                n_parallel=1,
                transport_resistance_model = cb.ChannelGasResistanceModel(A_ch=params['A_ch'], B_ch=params['B_ch'])
            ),
            liq_transport_model=cb.DarcyLiquidTransportModel(
                dry_wet_transition_parameter=params['wet-transition'],
            ),
            thermal_contact_resistance=0,
        ),
        an = cb.FuelCellSide(
            cl=NafionCL, has_mpl=False, gdl=GDL3Man,
            ch=cb.GasFlowChannel(
                reactant='h2',
                height=1e-3, 
                length=10e-4/2e-3,
                n_parallel=1,
                transport_resistance_model = cb.ChannelGasResistanceModel(A_ch=params['A_ch'],B_ch=params['B_ch'])
            ),
            thermal_contact_resistance=0,
        ),
        membrane = NafionHP
    )
    fc.name=cell
    return fc

# %%
def h(params): 
    fuel_cells = {cell: create_fuel_cell(params,  cell) for cell in cells}
    return np.concatenate(
         [compute_ui_curve(fuel_cells[cell], case) for case in case_list for cell in cells if case in exp_data[exp_data.cell_id == cell].case.unique()]
    )
exp_voltage_list = np.concatenate(
         [exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'U'] for case in case_list for cell in cells if case in exp_data[exp_data.cell_id == cell].case.unique()]
    )

def h2(params): 
    res_list = []
    fuel_cells = {cell: create_fuel_cell(params,  cell) for cell in cells}
    for case in case_list: 
        for cell in cells: 
            if case in exp_data[exp_data.cell_id == cell].case.unique(): 
                V_sim = compute_ui_curve(fuel_cells[cell], case)
                hfr_sim = 1e4*fuel_cells[cell].high_frequency_resistance() * (1-np.isnan(exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'hfr']))
                res_list += [V_sim, hfr_sim]
    return np.concatenate(res_list)
exp_res_list = []
for case in case_list: 
        for cell in cells: 
            if case in exp_data[exp_data.cell_id == cell].case.unique(): 
                V_exp = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'U']
                hfr_exp = np.nan_to_num(1e4*exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id==cell), 'hfr'],0)
                exp_res_list += [V_exp, hfr_exp]
exp_res_list = np.concatenate(exp_res_list)


model = cb.ParameterEstimationSteadyState(h2, {'AquivionD83-06-cl-proton-cond-exp': 1.85,
        'AquivionD83-06-pore-diameter':120e-9, 
        'NafionLQ1115-pore-diameter':120e-9, 
        'i0-c': 2.54e-4, 
        'gamma-c': 0.54,
        'NafionLQ1115-cl-proton-cond-exp':3.82, 
        'NafionHP-conductivity-exp': 1, 
        'Aquivion-cl-K-abs': 1e-14, 
        'Nafion-cl-K-abs': 1e-16,
        'NafionLQ1115-cl-proton-cond':9.4, 
        'AquivionD83-06-cl-proton-cond-exp': 3.82,
        'AquivionD83-06-cl-proton-cond': 83.6,
        'NafionLQ1115-cl-o2-diff-exp': 1.47,
        'AquivionD83-06-cl-o2-diff-exp':2.46,
        'elec-resistance':57e-7,
        'NafionHP-conductivity-correction': 1.12e+00, 
        'Nafion-memb-abs-constant': 6.43e-5, 
        'Aquivion-memb-abs-constant': 1.43e-5, 
        'NafionLQ1115-o2-diff': 2.72e-10,
        'AquivionD83-06-o2-diff': 9.11e-10,
        '3M-Deff-ratio': 0.35,  
        'wet-transition': 0.194, 
        'B_ch': 0.5221, 
        'A_ch': 10,  
        'kth-gdl':0.5,
        'Kabs': 1e-13
        })

'''
------------------------------
differential_evolution step 241: f(x)= 0.00038795627141368
------------------------------
RMSE : 19.7 mV
AquivionD83-06-cl-proton-cond (1, 100) 8.36e+01
NafionLQ1115-cl-proton-cond (1, 100) 9.40e+00
AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
NafionLQ1115-cl-proton-cond-exp (1, 4) 1.01e+00
AquivionD83-06-pore-diameter (1e-08, 2e-07) 1.77e-08
NafionLQ1115-pore-diameter (1e-08, 2e-07) 4.91e-08
AquivionD83-06-cl-o2-diff-exp (0, 4) 2.46e+00
NafionLQ1115-cl-o2-diff-exp (0, 4) 1.47e+00
NafionHP-conductivity-correction (0.5, 2) 1.12e+00
NafionHP-memb-abs-constant (5e-06, 0.0001) 6.43e-05
NafionLQ1115-o2-diff (1e-11, 2e-08) 2.72e-10
AquivionD83-06-o2-diff (1e-11, 2e-08) 20e-10
3M-Deff-ratio (0.2, 0.35) 3.23e-01
elec-resistance (3e-06, 6e-06) 5.68e-06
B_ch (0.1, 2) 5.22e-01
Kabs (1e-14, 1e-11) 6.37e-14
wet-transition (0.1, 0.33) 1.94e-01
kth-gdl (0.2, 5) 4.86e+00
------------------------------
'''

for i_cell, cell in enumerate(['LSC Nafion', 'SSC Aquivion']): 
    for k, case in enumerate(case_list): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]

        plt.figure(1)
        plt.plot(fuel_cell.current_density/1e4, U_sim, 'C{}-'.format(k) + ('-' if i_cell == 1 else ''))
        plt.plot(case_exp_data['i'].values, case_exp_data['U'].values, 'C{}'.format(k) + ('s' if i_cell == 0 else 'o'))
        plt.figure(2)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.gdl.water_saturation, 'C{}-'.format(k) + '-' if i_cell == 1 else '')
        plt.figure(3)
        plt.plot(fuel_cell.current_density/1e4, 1e7*fuel_cell.high_frequency_resistance(), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
        plt.figure(4)
        plt.plot(fuel_cell.current_density/1e4,fuel_cell.ca.calculate_gas_transport_resistance('h2o'), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
        plt.figure(5)
        plt.plot(fuel_cell.current_density/1e4,fuel_cell.membrane.water_content, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case )
exp_res_list
# Out:
# array([0.9005, 0.8797, 0.8499, 0.8012, 0.7396, 0.6973, 0.6398, 0.5997,
#        0.5493, 0.4999, 0.4495, 0.4005, 0.    , 0.    , 0.    , 0.0614,
#        0.0558, 0.0545, 0.0536, 0.054 , 0.0547, 0.056 , 0.0582, 0.0606,
#        0.8976, 0.8752, 0.8491, 0.8011, 0.7396, 0.7009, 0.639 , 0.6003,
#        0.5489, 0.4997, 0.4494, 0.4005, 0.    , 0.    , 0.    , 0.0514,
#        0.0423, 0.0412, 0.0411, 0.0413, 0.0423, 0.0439, 0.0471, 0.051 ,
#        0.8981, 0.8769, 0.8478, 0.8007, 0.7371, 0.6991, 0.6401, 0.5999,
#        0.5497, 0.5008, 0.4501, 0.4011, 0.    , 0.    , 0.129 , 0.103 ,
#        0.0886, 0.0851, 0.0834, 0.0868, 0.0903, 0.0946, 0.099 , 0.105 ,
#        0.8994, 0.8796, 0.8505, 0.8002, 0.7406, 0.698 , 0.6392, 0.5997,
#        0.5501, 0.4998, 0.451 , 0.4012, 0.    , 0.    , 0.121 , 0.0964,
#        0.0834, 0.0799, 0.0816, 0.0842, 0.0899, 0.0946, 0.101 , 0.106 ,
#        0.9004, 0.8819, 0.8523, 0.8017, 0.7409, 0.7016, 0.6414, 0.6013,
#        0.5509, 0.5002, 0.451 , 0.4008, 0.    , 0.    , 0.0688, 0.0575,
#        0.0542, 0.0539, 0.0529, 0.0534, 0.0552, 0.0571, 0.0599, 0.0633,
#        0.9018, 0.8824, 0.8522, 0.7976, 0.744 , 0.7017, 0.6416, 0.6016,
#        0.5505, 0.5006, 0.451 , 0.4013, 0.    , 0.    , 0.0596, 0.0525,
#        0.0504, 0.0508, 0.0517, 0.0527, 0.0546, 0.0569, 0.0599, 0.0631])

# %%
model.p['3M-Deff-ratio'] = 0.1
model.p['B_ch'] = 1e-0
model.p['A_ch'] = 3e-0
model.p['kth-gdl'] = .2
for i_cell, cell in enumerate(['LSC Nafion', 'SSC Aquivion']): 
    for k, case in enumerate(case_list): 
        fuel_cell = create_fuel_cell(model.p, cell)
       
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]
        S_exp = fuel_cell.membrane.dry_thickness / (case_exp_data['hfr']-39e-7) /  cb.calculate_arrhenius_term(10e6, 353.15, 303.15)
        plt.figure(1)
        #plt.plot(fuel_cell.current_density,S_exp ,'C{}'.format(k) + ('s' if i_cell == 0 else 'o'))
        #plt.plot(fuel_cell.current_density, fuel_cell.ca.liquid_flux,'C{}-'.format(k) + ('-' if i_cell == 0 else ''))
        plt.plot(fuel_cell.current_density, fuel_cell.ca.ch.get_vapor_concentration()/fuel_cell.ca.cl.get_saturation_concentration() + np.minimum(fuel_cell.h2o_production, fuel_cell.ca.max_water_vapor_removal()) * 
                 fuel_cell.ca.h2ov_transport_resistance / fuel_cell.ca.cl.get_saturation_concentration(), 'C{}-'.format(k) + ('-' if i_cell == 0 else ''))
        plt.figure(2)
        s = fuel_cell.ca.gdl.water_saturation
        plt.plot(fuel_cell.current_density,(S_exp + 0.326) ** (2./3) / 0.539 * 1.2, 'C{}'.format(k) + ('s' if i_cell == 0 else 'o'))
        plt.plot(fuel_cell.current_density,0.5*(
                (fuel_cell.membrane.equilibrium_water_content(fuel_cell.ca.ch.get_vapor_concentration()/fuel_cell.ca.cl.get_saturation_concentration() +
                                                              fuel_cell.h2o_production * fuel_cell.ca.h2ov_transport_resistance / fuel_cell.ca.cl.get_saturation_concentration())
                                                              ) + 
                 fuel_cell.membrane.equilibrium_water_content(fuel_cell.an.ch.get_vapor_concentration()/fuel_cell.an.cl.get_saturation_concentration())), 'C{}-'.format(k) + ('-' if i_cell == 0 else ''))
        plt.ylim([0,24])

# %%
model.set_unknown_params(
        [
        ('AquivionD83-06-cl-proton-cond', (1, 200), True, r'$\sigma_{Aquivion}$'),
        ('NafionLQ1115-cl-proton-cond', (1,200), True, r'$\sigma_{Nafion}$'),
        ('AquivionD83-06-cl-proton-cond-exp', (1, 4), True, r'$m\sigma_{Aquivion}$'),
        ('NafionLQ1115-cl-proton-cond-exp', (1,4), True, r'$m\sigma_{Nafion}$'),
        ('AquivionD83-06-pore-diameter', (1e-9, 200e-9), False, r'$dp_{Aquivion}$'),
        ('NafionLQ1115-pore-diameter', (1e-9, 200e-9), False, r'$dp_{Nafion}$'),
        ('AquivionD83-06-cl-o2-diff-exp', (0.5, 2), True, r'$\sigma_{Aquivion}$'),
        ('NafionLQ1115-cl-o2-diff-exp', (.5,2), True, r'$\sigma_{Nafion}$'),
        ('NafionHP-conductivity-correction', (0.5,2), True, '$k_{cond}$'),
        ('NafionHP-conductivity-exp', (1,2), True, '$m_{k}$'),
        ('Nafion-memb-abs-constant', (1e-6,1e-4), False, '$k_{abs}$'),
        ('Aquivion-memb-abs-constant', (1e-6,1e-4), False, '$k_{abs,Aq}$'),
        ('NafionLQ1115-o2-diff', (1e-12,10e-10), False, '$D_{O2,Nafion}$'),
        ('AquivionD83-06-o2-diff', (1e-12,10e-10), False, '$D_{O2,Aquivion}$'),
        ('3M-Deff-ratio', (0.15,0.5), True, '$D_{eff}/D$'),
        #
        ('i0-c',(1e-5,1e-3), False, '$i0_c$'),
        #('memb-thickness', (20e-6, 25e-6), True, '$t_m$'), 
        ('elec-resistance', (20e-7,60e-7), True, '$R_{elec}$'),
        
        ('A_ch', (1e-4, 2), False, '$A_{ch}$'),
        ('B_ch', (1e-4, 2), False, '$B_{ch}$'),
        #('ionomer-vol-fraction', (0.15,0.4), True, r'$\varepsilon_{ion}$'),
        ('Kabs', (1e-13,1e-11), False, '$K_{l}$'),
        # ('Aquivion-cl-K-abs', (1e-18,1e-11), False, '$K_{l}$'),
        # ('Nafion-cl-K-abs', (1e-18,1e-11), False, '$K_{l}$'),
        #('wet-saturation', (0.1,0.5), True, '$s_{wet}$'),
        ('wet-transition', (0.1, 0.4), True, '$alpha_{wet}$'),
        #('critical-damkholer', (0.8,2), True, '$Da_{w,cr}$'),
        ('kth-gdl', (0.2,5), True, '$k_{GDL}$'),
        #('R-ch-correction', (0.,1.), True, '$R_{ch}$'),
        
        #('ionomer-vol-fraction', (0.1,.5), True, '$\epsilon_{ion}$'),
        #('E-act-ca', (50e3, 100e3), True, '$E_{act, ca}$'),
        #('omega-PtO', (1e6, 10e6), True, '$\omega_{PtO}$'),
        #('memb-cond-corr', (0.1,10), True,'$f_{mb}$'),
        #('memb-water-diff', (1e-10, 40e-10), True, '$D_{\lambda}$'),
        #('memb-abs-constant', (1e-7, 1e-4), False, '$k_{abs}$'),
        ]
    )

# %%
cosPhi_med_ij, norm_s_i, S_med, S_std, S_med_i, S_std_i, S_n, n_valid = model.compute_global_sensitivity(t=0, m=6,  
                                                                                                         check_samples=True,
                                                                                                         y_exp=exp_res_list, 
                                                                                                         res_limit=0.02)

# %%
print('Number of valid samples: {:d}'.format(n_valid))
fig1, ax1 = model.plot_global_sensitivity(xlabel_angle=45) 
fig2, ax2 = model.plot_colinearity_map(xlabel_angle=45, cmap='Blues',figsize=(7,6))

plt.show()
# Out:
# Number of valid samples: 19

# %%
sol, p_est = model.estimate(exp_res_list, t=0, print_iterations=True, popsize=20, ftol=1e-5)
model.p.update({param: v for param, v in zip(model.p_i_name, p_est)})
# Out:
# differential_evolution step 1: f(x)= 0.0026045266124800773
# ------------------------------
# RMSE : 51.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.26e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.56e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.08e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.22e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.96e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.92e-08
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.81e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 9.95e-01
# NafionHP-conductivity-correction (0.5, 2) 9.16e-01
# NafionHP-conductivity-exp (1, 2) 1.28e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.93e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 3.96e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 9.14e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 6.60e-10
# 3M-Deff-ratio (0.15, 0.5) 1.92e-01
# i0-c (1e-05, 0.001) 9.52e-05
# elec-resistance (2e-06, 6e-06) 5.67e-06
# A_ch (0.0001, 2) 2.53e-01
# B_ch (0.0001, 2) 1.85e-03
# Kabs (1e-13, 1e-11) 2.37e-13
# wet-transition (0.1, 0.4) 3.44e-01
# kth-gdl (0.2, 5) 2.40e+00
# ------------------------------
# differential_evolution step 2: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 3: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 4: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 5: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 6: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 7: f(x)= 0.0012277866624786614
# ------------------------------
# RMSE : 35.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.30e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.48e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 2.97e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 1.08e-08
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.15e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.67e-01
# NafionHP-conductivity-correction (0.5, 2) 1.50e+00
# NafionHP-conductivity-exp (1, 2) 1.14e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.65e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.26e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.99e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.05e-10
# 3M-Deff-ratio (0.15, 0.5) 1.54e-01
# i0-c (1e-05, 0.001) 9.22e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 4.39e-03
# B_ch (0.0001, 2) 5.80e-04
# Kabs (1e-13, 1e-11) 1.90e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.26e+00
# ------------------------------
# differential_evolution step 8: f(x)= 0.0011562736512500229
# ------------------------------
# RMSE : 34.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.73e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.27e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.43e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.03e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.00e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.97e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.53e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.96e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.16e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.02e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.07e-10
# 3M-Deff-ratio (0.15, 0.5) 1.55e-01
# i0-c (1e-05, 0.001) 8.84e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.53e-03
# B_ch (0.0001, 2) 6.56e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.19e-01
# kth-gdl (0.2, 5) 2.29e+00
# ------------------------------
# differential_evolution step 9: f(x)= 0.0011562736512500229
# ------------------------------
# RMSE : 34.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.73e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.27e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.43e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.03e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.00e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.97e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.53e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.96e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.16e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.02e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.07e-10
# 3M-Deff-ratio (0.15, 0.5) 1.55e-01
# i0-c (1e-05, 0.001) 8.84e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.53e-03
# B_ch (0.0001, 2) 6.56e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.19e-01
# kth-gdl (0.2, 5) 2.29e+00
# ------------------------------
# differential_evolution step 10: f(x)= 0.0011562736512500229
# ------------------------------
# RMSE : 34.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.73e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.27e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.43e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.03e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.00e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.97e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.53e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.96e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.16e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.02e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.07e-10
# 3M-Deff-ratio (0.15, 0.5) 1.55e-01
# i0-c (1e-05, 0.001) 8.84e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.53e-03
# B_ch (0.0001, 2) 6.56e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.19e-01
# kth-gdl (0.2, 5) 2.29e+00
# ------------------------------
# differential_evolution step 11: f(x)= 0.0011562736512500229
# ------------------------------
# RMSE : 34.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.73e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.27e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.43e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.03e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.00e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.97e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.53e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.96e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.16e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.02e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.07e-10
# 3M-Deff-ratio (0.15, 0.5) 1.55e-01
# i0-c (1e-05, 0.001) 8.84e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.53e-03
# B_ch (0.0001, 2) 6.56e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.19e-01
# kth-gdl (0.2, 5) 2.29e+00
# ------------------------------
# differential_evolution step 12: f(x)= 0.0011562736512500229
# ------------------------------
# RMSE : 34.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.73e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.27e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.43e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.03e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 7.00e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.97e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.53e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.96e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.16e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.02e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.07e-10
# 3M-Deff-ratio (0.15, 0.5) 1.55e-01
# i0-c (1e-05, 0.001) 8.84e-05
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.53e-03
# B_ch (0.0001, 2) 6.56e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.19e-01
# kth-gdl (0.2, 5) 2.29e+00
# ------------------------------
# differential_evolution step 13: f(x)= 0.0011275079114357054
# ------------------------------
# RMSE : 33.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.77e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.65e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.00e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.04e-10
# 3M-Deff-ratio (0.15, 0.5) 1.56e-01
# i0-c (1e-05, 0.001) 9.07e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 6.58e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.30e+00
# ------------------------------
# differential_evolution step 14: f(x)= 0.0011275079114357054
# ------------------------------
# RMSE : 33.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.77e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.65e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.00e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.04e-10
# 3M-Deff-ratio (0.15, 0.5) 1.56e-01
# i0-c (1e-05, 0.001) 9.07e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 6.58e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.30e+00
# ------------------------------
# differential_evolution step 15: f(x)= 0.0011275079114357054
# ------------------------------
# RMSE : 33.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.77e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.65e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.00e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.04e-10
# 3M-Deff-ratio (0.15, 0.5) 1.56e-01
# i0-c (1e-05, 0.001) 9.07e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 6.58e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.30e+00
# ------------------------------
# differential_evolution step 16: f(x)= 0.0011275079114357054
# ------------------------------
# RMSE : 33.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.77e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.65e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.00e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.04e-10
# 3M-Deff-ratio (0.15, 0.5) 1.56e-01
# i0-c (1e-05, 0.001) 9.07e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 6.58e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.30e+00
# ------------------------------
# differential_evolution step 17: f(x)= 0.0011275079114357054
# ------------------------------
# RMSE : 33.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.77e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.65e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.74e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.00e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 4.04e-10
# 3M-Deff-ratio (0.15, 0.5) 1.56e-01
# i0-c (1e-05, 0.001) 9.07e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 6.58e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 2.30e+00
# ------------------------------
# differential_evolution step 18: f(x)= 0.0011215469111314387
# ------------------------------
# RMSE : 33.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.39e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.78e-01
# NafionHP-conductivity-correction (0.5, 2) 1.49e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.58e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.47e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.95e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 9.54e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.69e-03
# B_ch (0.0001, 2) 6.74e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.17e-01
# kth-gdl (0.2, 5) 2.32e+00
# ------------------------------
# differential_evolution step 19: f(x)= 0.0011215469111314387
# ------------------------------
# RMSE : 33.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.39e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.78e-01
# NafionHP-conductivity-correction (0.5, 2) 1.49e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.58e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.47e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.95e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 9.54e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.69e-03
# B_ch (0.0001, 2) 6.74e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.17e-01
# kth-gdl (0.2, 5) 2.32e+00
# ------------------------------
# differential_evolution step 20: f(x)= 0.0011215469111314387
# ------------------------------
# RMSE : 33.5 mV
# AquivionD83-06-cl-proton-cond (1, 200) 9.56e+01
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.39e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.52e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.78e-01
# NafionHP-conductivity-correction (0.5, 2) 1.49e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.58e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.47e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.95e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 9.54e-05
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.69e-03
# B_ch (0.0001, 2) 6.74e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.17e-01
# kth-gdl (0.2, 5) 2.32e+00
# ------------------------------
# differential_evolution step 21: f(x)= 0.001072115804692348
# ------------------------------
# RMSE : 32.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.05e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.74e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.99e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.69e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.76e-01
# NafionHP-conductivity-correction (0.5, 2) 1.56e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.12e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.29e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.94e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.16e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.92e-03
# B_ch (0.0001, 2) 1.36e-03
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.17e-01
# kth-gdl (0.2, 5) 2.00e+00
# ------------------------------
# differential_evolution step 22: f(x)= 0.0010476067228186582
# ------------------------------
# RMSE : 32.4 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.24e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.42e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.75e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.77e-01
# NafionHP-conductivity-correction (0.5, 2) 1.58e+00
# NafionHP-conductivity-exp (1, 2) 1.15e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.77e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.72e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.07e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.18e-04
# elec-resistance (2e-06, 6e-06) 5.96e-06
# A_ch (0.0001, 2) 3.81e-03
# B_ch (0.0001, 2) 1.39e-03
# Kabs (1e-13, 1e-11) 1.78e-13
# wet-transition (0.1, 0.4) 3.17e-01
# kth-gdl (0.2, 5) 1.86e+00
# ------------------------------
# differential_evolution step 23: f(x)= 0.001023196002753136
# ------------------------------
# RMSE : 32.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.69e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.74e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.80e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.82e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.56e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.04e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.19e-04
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.42e-03
# B_ch (0.0001, 2) 6.80e-04
# Kabs (1e-13, 1e-11) 1.89e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.90e+00
# ------------------------------
# differential_evolution step 24: f(x)= 0.0010218246407270636
# ------------------------------
# RMSE : 32.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.36e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.66e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.74e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.80e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.31e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.05e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.19e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.41e-03
# B_ch (0.0001, 2) 6.98e-04
# Kabs (1e-13, 1e-11) 1.87e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.83e+00
# ------------------------------
# differential_evolution step 25: f(x)= 0.0010218246407270636
# ------------------------------
# RMSE : 32.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.36e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.66e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.74e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.80e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.31e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.05e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.19e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.41e-03
# B_ch (0.0001, 2) 6.98e-04
# Kabs (1e-13, 1e-11) 1.87e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.83e+00
# ------------------------------
# differential_evolution step 26: f(x)= 0.0010218246407270636
# ------------------------------
# RMSE : 32.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.36e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.04e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.66e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.74e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.80e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 8.31e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.05e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.19e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.41e-03
# B_ch (0.0001, 2) 6.98e-04
# Kabs (1e-13, 1e-11) 1.87e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.83e+00
# ------------------------------
# differential_evolution step 27: f(x)= 0.0010122524085765408
# ------------------------------
# RMSE : 31.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.08e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.60e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.79e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 9.14e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.50e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.06e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.22e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.27e-03
# B_ch (0.0001, 2) 6.80e-04
# Kabs (1e-13, 1e-11) 1.87e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.78e+00
# ------------------------------
# differential_evolution step 28: f(x)= 0.0010114567891896787
# ------------------------------
# RMSE : 31.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.16e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.58e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.81e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.90e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.06e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.21e-04
# elec-resistance (2e-06, 6e-06) 5.96e-06
# A_ch (0.0001, 2) 3.21e-03
# B_ch (0.0001, 2) 6.33e-04
# Kabs (1e-13, 1e-11) 1.78e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.78e+00
# ------------------------------
# differential_evolution step 29: f(x)= 0.0010114567891896787
# ------------------------------
# RMSE : 31.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.16e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.58e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.81e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.90e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.06e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.21e-04
# elec-resistance (2e-06, 6e-06) 5.96e-06
# A_ch (0.0001, 2) 3.21e-03
# B_ch (0.0001, 2) 6.33e-04
# Kabs (1e-13, 1e-11) 1.78e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.78e+00
# ------------------------------
# differential_evolution step 30: f(x)= 0.0010114567891896787
# ------------------------------
# RMSE : 31.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.16e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.58e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.81e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.90e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.06e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.21e-04
# elec-resistance (2e-06, 6e-06) 5.96e-06
# A_ch (0.0001, 2) 3.21e-03
# B_ch (0.0001, 2) 6.33e-04
# Kabs (1e-13, 1e-11) 1.78e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.78e+00
# ------------------------------
# differential_evolution step 31: f(x)= 0.0010114567891896787
# ------------------------------
# RMSE : 31.8 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.16e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.58e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.95e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.81e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.90e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.51e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.06e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.21e-04
# elec-resistance (2e-06, 6e-06) 5.96e-06
# A_ch (0.0001, 2) 3.21e-03
# B_ch (0.0001, 2) 6.33e-04
# Kabs (1e-13, 1e-11) 1.78e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.78e+00
# ------------------------------
# differential_evolution step 32: f(x)= 0.001004349750535053
# ------------------------------
# RMSE : 31.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.31e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.13e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.79e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.87e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.50e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.63e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.07e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.98e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.12e-04
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.32e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.72e-13
# wet-transition (0.1, 0.4) 3.16e-01
# kth-gdl (0.2, 5) 1.81e+00
# ------------------------------
# differential_evolution step 33: f(x)= 0.001004349750535053
# ------------------------------
# RMSE : 31.7 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.31e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.13e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.79e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.87e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.16e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.50e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.63e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.07e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.98e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.12e-04
# elec-resistance (2e-06, 6e-06) 5.97e-06
# A_ch (0.0001, 2) 3.32e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.72e-13
# wet-transition (0.1, 0.4) 3.16e-01
# kth-gdl (0.2, 5) 1.81e+00
# ------------------------------
# differential_evolution step 34: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 35: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 36: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 37: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 38: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 39: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 40: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 41: f(x)= 0.0009992389609687904
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.03e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.36e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.37e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.20e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.70e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 2.98e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.90e-01
# NafionHP-conductivity-correction (0.5, 2) 1.57e+00
# NafionHP-conductivity-exp (1, 2) 1.17e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.33e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.57e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.08e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.99e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.15e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.22e-03
# B_ch (0.0001, 2) 6.11e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.76e+00
# ------------------------------
# differential_evolution step 42: f(x)= 0.0009988461099113813
# ------------------------------
# RMSE : 31.6 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.08e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.29e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.35e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.43e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.86e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.02e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.73e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.85e-01
# NafionHP-conductivity-correction (0.5, 2) 1.70e+00
# NafionHP-conductivity-exp (1, 2) 1.20e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.67e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 7.29e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.01e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.97e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.04e-04
# elec-resistance (2e-06, 6e-06) 5.95e-06
# A_ch (0.0001, 2) 3.47e-03
# B_ch (0.0001, 2) 5.73e-04
# Kabs (1e-13, 1e-11) 1.80e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.72e+00
# ------------------------------
# differential_evolution step 43: f(x)= 0.0009723194464999598
# ------------------------------
# RMSE : 31.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.12e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.37e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.35e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.62e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.85e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.04e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.71e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 8.86e-01
# NafionHP-conductivity-correction (0.5, 2) 1.70e+00
# NafionHP-conductivity-exp (1, 2) 1.15e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.12e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 8.23e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 5.87e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.94e-10
# 3M-Deff-ratio (0.15, 0.5) 1.57e-01
# i0-c (1e-05, 0.001) 1.19e-04
# elec-resistance (2e-06, 6e-06) 5.92e-06
# A_ch (0.0001, 2) 3.08e-03
# B_ch (0.0001, 2) 7.04e-04
# Kabs (1e-13, 1e-11) 1.75e-13
# wet-transition (0.1, 0.4) 3.15e-01
# kth-gdl (0.2, 5) 1.69e+00
# ------------------------------
# differential_evolution step 44: f(x)= 0.0009585459896586582
# ------------------------------
# RMSE : 31.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.34e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.65e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.60e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.02e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.70e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.07e+00
# NafionHP-conductivity-correction (0.5, 2) 1.70e+00
# NafionHP-conductivity-exp (1, 2) 1.13e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.99e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.59e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.10e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.91e-10
# 3M-Deff-ratio (0.15, 0.5) 1.58e-01
# i0-c (1e-05, 0.001) 1.12e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.60e-03
# B_ch (0.0001, 2) 6.63e-04
# Kabs (1e-13, 1e-11) 1.71e-13
# wet-transition (0.1, 0.4) 3.16e-01
# kth-gdl (0.2, 5) 1.63e+00
# ------------------------------
# differential_evolution step 45: f(x)= 0.0009585459896586582
# ------------------------------
# RMSE : 31.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.34e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.65e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.60e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.02e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.70e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.07e+00
# NafionHP-conductivity-correction (0.5, 2) 1.70e+00
# NafionHP-conductivity-exp (1, 2) 1.13e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 7.99e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 6.59e-06
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.10e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.91e-10
# 3M-Deff-ratio (0.15, 0.5) 1.58e-01
# i0-c (1e-05, 0.001) 1.12e-04
# elec-resistance (2e-06, 6e-06) 5.98e-06
# A_ch (0.0001, 2) 3.60e-03
# B_ch (0.0001, 2) 6.63e-04
# Kabs (1e-13, 1e-11) 1.71e-13
# wet-transition (0.1, 0.4) 3.16e-01
# kth-gdl (0.2, 5) 1.63e+00
# ------------------------------
# differential_evolution step 46: f(x)= 0.0009585459896586582
# ------------------------------
# RMSE : 31.0 mV
# AquivionD83-06-cl-proton-cond (1, 200) 1.02e+02
# NafionLQ1115-cl-proton-cond (1, 200) 1.21e+02
# AquivionD83-06-cl-proton-cond-exp (1, 4) 2.34e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 3.65e+00
# ...
# kth-gdl (0.2, 5) 1.24e+00
# ------------------------------
# differential_evolution step 317: f(x)= 0.00044768481976907755
# ------------------------------
# RMSE : 21.2 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.17e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.53e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.49e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.12e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.17e+00
# NafionHP-conductivity-correction (0.5, 2) 1.36e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.54e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.13e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.10e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.95e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.52e-03
# B_ch (0.0001, 2) 1.47e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.24e+00
# ------------------------------
# differential_evolution step 318: f(x)= 0.0004472126627497242
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.53e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.49e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.12e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.17e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 6.47e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.10e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.10e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.95e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.12e-03
# B_ch (0.0001, 2) 1.49e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.24e+00
# ------------------------------
# differential_evolution step 319: f(x)= 0.00044660874872111254
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.47e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.10e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.16e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.69e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.12e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.11e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.98e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.10e-03
# B_ch (0.0001, 2) 1.48e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.23e+00
# ------------------------------
# differential_evolution step 320: f(x)= 0.00044660874872111254
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.47e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.10e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.16e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.69e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.12e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.11e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.98e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.10e-03
# B_ch (0.0001, 2) 1.48e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.23e+00
# ------------------------------
# differential_evolution step 321: f(x)= 0.00044660874872111254
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.47e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.10e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.16e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.69e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.12e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.11e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.98e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.10e-03
# B_ch (0.0001, 2) 1.48e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.23e+00
# ------------------------------
# differential_evolution step 322: f(x)= 0.00044642378920441904
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.52e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.47e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.10e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.64e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.16e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.61e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.12e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.11e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.95e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.12e-03
# B_ch (0.0001, 2) 1.46e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.23e+00
# ------------------------------
# differential_evolution step 323: f(x)= 0.0004460370997761418
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.46e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.09e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.16e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.02e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.13e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.11e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.98e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.08e-03
# B_ch (0.0001, 2) 1.46e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.22e+00
# ------------------------------
# differential_evolution step 324: f(x)= 0.0004459551793349837
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.13e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.45e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.08e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.15e+00
# NafionHP-conductivity-correction (0.5, 2) 1.34e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.56e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.13e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.12e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.00e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.46e-03
# B_ch (0.0001, 2) 1.46e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.21e+00
# ------------------------------
# differential_evolution step 325: f(x)= 0.0004459551793349837
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.13e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.51e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.45e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.08e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.15e+00
# NafionHP-conductivity-correction (0.5, 2) 1.34e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.56e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.13e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.12e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.00e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.46e-03
# B_ch (0.0001, 2) 1.46e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.21e+00
# ------------------------------
# differential_evolution step 326: f(x)= 0.0004455172284990817
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.15e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.50e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.42e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.07e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.14e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.15e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.11e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.12e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.02e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.16e-03
# B_ch (0.0001, 2) 1.44e-02
# Kabs (1e-13, 1e-11) 1.13e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.21e+00
# ------------------------------
# differential_evolution step 327: f(x)= 0.00044532171700095214
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.16e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.50e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.43e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.08e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.14e+00
# NafionHP-conductivity-correction (0.5, 2) 1.36e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.82e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.11e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.13e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.04e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.40e-03
# B_ch (0.0001, 2) 1.43e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.20e+00
# ------------------------------
# differential_evolution step 328: f(x)= 0.00044532171700095214
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.16e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.50e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.43e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.08e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.14e+00
# NafionHP-conductivity-correction (0.5, 2) 1.36e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.82e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.11e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.13e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.04e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.40e-03
# B_ch (0.0001, 2) 1.43e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.20e+00
# ------------------------------
# differential_evolution step 329: f(x)= 0.00044532171700095214
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.16e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.50e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.43e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.08e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.14e+00
# NafionHP-conductivity-correction (0.5, 2) 1.36e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.82e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.11e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.13e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 4.04e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.40e-03
# B_ch (0.0001, 2) 1.43e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.20e+00
# ------------------------------
# differential_evolution step 330: f(x)= 0.00044491872817484853
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.17e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.50e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.42e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.07e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.63e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.13e+00
# NafionHP-conductivity-correction (0.5, 2) 1.36e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 4.21e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.09e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.14e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.97e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.79e-03
# B_ch (0.0001, 2) 1.43e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.19e+00
# ------------------------------
# differential_evolution step 331: f(x)= 0.0004438834002881208
# ------------------------------
# RMSE : 21.1 mV
# AquivionD83-06-cl-proton-cond (1, 200) 2.17e+00
# NafionLQ1115-cl-proton-cond (1, 200) 1.48e+00
# AquivionD83-06-cl-proton-cond-exp (1, 4) 1.00e+00
# NafionLQ1115-cl-proton-cond-exp (1, 4) 1.00e+00
# AquivionD83-06-pore-diameter (1e-09, 2e-07) 6.35e-09
# NafionLQ1115-pore-diameter (1e-09, 2e-07) 3.09e-09
# AquivionD83-06-cl-o2-diff-exp (0.5, 2) 1.62e+00
# NafionLQ1115-cl-o2-diff-exp (0.5, 2) 1.11e+00
# NafionHP-conductivity-correction (0.5, 2) 1.35e+00
# NafionHP-conductivity-exp (1, 2) 1.00e+00
# Nafion-memb-abs-constant (1e-06, 0.0001) 5.08e-06
# Aquivion-memb-abs-constant (1e-06, 0.0001) 1.10e-05
# NafionLQ1115-o2-diff (1e-12, 1e-09) 6.14e-10
# AquivionD83-06-o2-diff (1e-12, 1e-09) 3.87e-10
# 3M-Deff-ratio (0.15, 0.5) 1.59e-01
# i0-c (1e-05, 0.001) 3.97e-04
# elec-resistance (2e-06, 6e-06) 6.00e-06
# A_ch (0.0001, 2) 1.77e-03
# B_ch (0.0001, 2) 1.43e-02
# Kabs (1e-13, 1e-11) 1.12e-13
# wet-transition (0.1, 0.4) 3.18e-01
# kth-gdl (0.2, 5) 1.14e+00
# ------------------------------

# %%
exp_data = pd.read_csv(f'../data/garsany_et_al_2018/Garsany2018-gz.csv', sep=';', decimal=',')
exp_data = exp_data[exp_data.cell_id != 'GORE']
cells = exp_data.cell_id.unique()
for cell in cells: 
    exp_data.loc[exp_data.cell_id  == cell, 'case'] = exp_data.loc[exp_data.cell_id  == cell, ['T_stack', 'rh_ca', 'rh_an', 'p_ca_out']].sum(axis=1)
case_list = [1,2,3]
exp_data['case'] = exp_data['case'].map(dict(zip(exp_data['case'].unique(),case_list)))
exp_data = exp_data

# %%
case_name = [
    
    'Nafion LSC - 1 bar - 50% RH', 
    'Nafion LSC - 1 bar - 100% RH', 
    'Nafion LSC - 1.5 bar - 100% RH', 
    'Aquivion SSC - 1 bar - 50% RH', 
    'Aquivion SSC - 1 bar - 100% RH', 
    
    'Aquivion SSC - 1.5 bar - 100% RH', 
   
]
labels = []
fig1, ax1 = plt.subplots(1, figsize=(6,3))
fig2, ax2 = plt.subplots(1,1, figsize=(6,3))
for i_cell, cell in enumerate(['LSC Nafion', 'SSC Aquivion']): 
    for k, case in enumerate(case_list): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]
        U_exp = case_exp_data['U'].values
        res = U_exp - U_sim
        RMSE = np.sqrt(np.dot(res, res) / len(res)) * 1000
        
        l2, = ax1.plot(fuel_cell.current_density/1e4, U_exp, 'C{}'.format(k) + ('s' if i_cell == 1 else 'o'))
        l, = ax1.plot(fuel_cell.current_density/1e4, U_sim, 'C{}-'.format(k) + ('-' if i_cell == 1 else ''), label='{:.0f} mV'.format(RMSE))
        labels.append(l)
        leg_RMSE = ax1.legend(title='RMSE', bbox_to_anchor=(1.5,1), loc='upper left')
       
        ax2.plot(fuel_cell.current_density/1e4, 1e7*fuel_cell.high_frequency_resistance(), 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        ax2.plot(case_exp_data['i'].values, 1e7*case_exp_data['hfr'].values, 'C{}'.format(k) + ('s' if i_cell == 1 else 'o'))
        
        plt.figure(3)
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.bi, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.bi, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )
        # plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.pe, 'C{}-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=0.5 )

plt.figure(1)
leg1 = plt.legend(handles=labels[0:3], labels=['1.0 bar - 50% RH', '1.0 bar - 100% RH', '1.5 bar - 100% RH', ], bbox_to_anchor=(1.04,1), loc='upper left')
leg2 = plt.legend(handles=(labels[0], labels[3]), labels=['Nafion LSC', 'Aquivion SSC'], bbox_to_anchor=(1.04,0.6), loc='upper left')
leg3 = plt.legend(handles=(l, l2), labels=['Sim.', 'Exp.'], bbox_to_anchor=(1.04,0.3), loc='upper left')
ax1.add_artist(leg_RMSE)
ax1.add_artist(leg1)
ax1.add_artist(leg2)
ax1.set_xlabel('Current density (A/cm$^2$)')
ax1.set_ylabel('Cell voltage (V)')
fig1.tight_layout()
fig1.savefig('./test_figure.png', bbox_extra_artists=(leg1,leg_RMSE), bbox_inches='tight')

# %%
for i_cell, cell in enumerate(['LSC Nafion']): 
    for k, case in enumerate([1,2,3]): 
        fuel_cell = create_fuel_cell(model.p, cell)
        U_sim = compute_ui_curve(fuel_cell, case)
        case_exp_data = exp_data.loc[np.logical_and(exp_data.case == case, exp_data.cell_id == cell)]
        U_exp = case_exp_data['U'].values
        res = U_exp - U_sim
        RMSE = np.sqrt(np.dot(res, res) / len(res)) * 1000
        
        plt.figure(1)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.water_content)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.equiv_water_content)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.equiv_water_content)
        
        plt.figure(3)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.ca.gdl.water_saturation)
        plt.figure(2)
        plt.plot(fuel_cell.current_density/1e4, fuel_cell.high_frequency_resistance())
        #plt.plot(fuel_cell.current_density/1e4, fuel_cell.an.bi, 'C1-' + '-' if i_cell == 1 else '', label=case, alpha=1 )
       # plt.plot(fuel_cell.current_density/1e4, fuel_cell.membrane.pe, 'C2-'.format(k) + '-' if i_cell == 1 else '', label=case, alpha=1 )
